# %%
import pickle
#Load Dictionary
with open('transcripts_timestamps_links.pkl', 'rb') as infile:
    transcripts = pickle.load(infile)

# %%
transcripts[80]
# Out:
# {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#  'Text': 'predict the next token the next word',
#  'TimeStamp': 234.239,
#  'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=234s'}

# %%
transcript = YouTubeTranscriptApi.get_transcript('a86iTyxnFE4')

# %%
transcript
# Out:
# [{'text': 'welcome back and in this video we are',
#   'start': 0.48,
#   'duration': 6.68},
#  {'text': 'going to run our first llm open source',
#   'start': 3.719,
#   'duration': 6.92},
#  {'text': 'llm this will be an llm from Google and',
#   'start': 7.16,
#   'duration': 6.0},
#  {'text': 'we will use a huging face library for',
#   'start': 10.639,
#   'duration': 6.241},
#  {'text': 'that um and uh if you words about huging',
#   'start': 13.16,
#   'duration': 8.08},
#  {'text': 'face so they have um so Hing face is the',
#   'start': 16.88,
#   'duration': 9.36},
#  {'text': 'way I see it this is a place for that',
#   'start': 21.24,
#   'duration': 7.4},
#  {'text': 'hosts model so you can upload any model',
#   'start': 26.24,
#   'duration': 4.999},
#  {'text': 'there and this is kind', 'start': 28.64, 'duration': 6.079},
#  {'text': 'of a model repository in a way so if you',
#   'start': 31.239,
#   'duration': 7.401},
#  {'text': 'want to uh find a model usually you go',
#   'start': 34.719,
#   'duration': 6.481},
#  {'text': 'there and many companies uh like for',
#   'start': 38.64,
#   'duration': 5.2},
#  {'text': 'example Google publish their models on',
#   'start': 41.2,
#   'duration': 5.679},
#  {'text': "Hing face so there's a place called",
#   'start': 43.84,
#   'duration': 7.199},
#  {'text': 'Kagen face Hub and this is the place for',
#   'start': 46.879,
#   'duration': 6.801},
#  {'text': 'models and we can see that um like right',
#   'start': 51.039,
#   'duration': 5.04},
#  {'text': 'now on their website and we see that',
#   'start': 53.68,
#   'duration': 3.76},
#  {'text': 'there are trending', 'start': 56.079, 'duration': 5.96},
#  {'text': 'models and I think um this quen 2 this',
#   'start': 57.44,
#   'duration': 7.84},
#  {'text': "is an llm and they have like not it's",
#   'start': 62.039,
#   'duration': 5.961},
#  {'text': 'not only llm there are many different',
#   'start': 65.28,
#   'duration': 6.6},
#  {'text': 'models and this what you have chpt 40 I',
#   'start': 68.0,
#   'duration': 7.68},
#  {'text': "don't know what is that it's", 'start': 71.88, 'duration': 3.8},
#  {'text': 'probably okay I will not attempt',
#   'start': 77.52,
#   'duration': 6.919},
#  {'text': 'to uh go there the important thing to',
#   'start': 80.56,
#   'duration': 6.68},
#  {'text': 'know that uh the library we will use',
#   'start': 84.439,
#   'duration': 5.081},
#  {'text': 'will actually go to hgen face Hub to',
#   'start': 87.24,
#   'duration': 3.48},
#  {'text': 'fetch', 'start': 89.52, 'duration': 3.879},
#  {'text': 'um the model', 'start': 90.72, 'duration': 6.2},
#  {'text': 'files okay so we have that and we',
#   'start': 93.399,
#   'duration': 6.0},
#  {'text': 'install actually these transformers this',
#   'start': 96.92,
#   'duration': 5.04},
#  {'text': 'is a library by hgen phase and when we',
#   'start': 99.399,
#   'duration': 6.521},
#  {'text': 'use Transformers and when we download',
#   'start': 101.96,
#   'duration': 6.08},
#  {'text': 'models using trans the Transformers',
#   'start': 105.92,
#   'duration': 4.559},
#  {'text': 'Library we actually go to huging face to',
#   'start': 108.04,
#   'duration': 5.039},
#  {'text': 'fetch this library to to fetch these',
#   'start': 110.479,
#   'duration': 7.32},
#  {'text': 'models and um there we will use this',
#   'start': 113.079,
#   'duration': 8.921},
#  {'text': 'model Google flan T5 XL so this will be',
#   'start': 117.799,
#   'duration': 7.36},
#  {'text': 'the first model and right now I am just',
#   'start': 122.0,
#   'duration': 6.28},
#  {'text': 'going to Google this model and this is',
#   'start': 125.159,
#   'duration': 7.121},
#  {'text': 'the first result so we are now in on',
#   'start': 128.28,
#   'duration': 7.44},
#  {'text': 'hgen face in the hgen face Hub on the',
#   'start': 132.28,
#   'duration': 6.8},
#  {'text': 'model description of um this model',
#   'start': 135.72,
#   'duration': 6.159},
#  {'text': 'right and so this link describes the',
#   'start': 139.08,
#   'duration': 7.6},
#  {'text': 'model I will put it now here in the link',
#   'start': 141.879,
#   'duration': 7.72},
#  {'text': 'in in the links session you can check it',
#   'start': 146.68,
#   'duration': 4.32},
#  {'text': 'out', 'start': 149.599, 'duration': 4.561},
#  {'text': 'later and the interesting part usually',
#   'start': 151.0,
#   'duration': 5.879},
#  {'text': 'this is like rme or GitHub projects',
#   'start': 154.16,
#   'duration': 5.68},
#  {'text': 'except this rme is for', 'start': 156.879, 'duration': 6.601},
#  {'text': 'models and usually there is a very good',
#   'start': 159.84,
#   'duration': 7.479},
#  {'text': 'um examples of how you can run the model',
#   'start': 163.48,
#   'duration': 6.36},
#  {'text': 'so there is like how you run it on a CPU',
#   'start': 167.319,
#   'duration': 4.881},
#  {'text': "we have a GPU machine or at least I'm",
#   'start': 169.84,
#   'duration': 4.039},
#  {'text': 'showing it on the GPU machine you can',
#   'start': 172.2,
#   'duration': 4.56},
#  {'text': 'try it on CPU but usually it takes some',
#   'start': 173.879,
#   'duration': 6.44},
#  {'text': 'time to do that and I just copy this',
#   'start': 176.76,
#   'duration': 8.119},
#  {'text': 'piece of code and I will put it',
#   'start': 180.319,
#   'duration': 8.321},
#  {'text': "here so I'll split it into multiple",
#   'start': 184.879,
#   'duration': 6.121},
#  {'text': 'blocks so first we do the', 'start': 188.64, 'duration': 5.159},
#  {'text': 'import and here we need to import two',
#   'start': 191.0,
#   'duration': 5.599},
#  {'text': 'things the generator and tokenizer so',
#   'start': 193.799,
#   'duration': 5.561},
#  {'text': "the difference between them well it's",
#   'start': 196.599,
#   'duration': 4.881},
#  {'text': 'actually kind of self-explanatory if you',
#   'start': 199.36,
#   'duration': 4.28},
#  {'text': 'look at the code so there is one thing',
#   'start': 201.48,
#   'duration': 4.92},
#  {'text': 'that is in the model this is the actual',
#   'start': 203.64,
#   'duration': 4.48},
#  {'text': 'model the actual', 'start': 206.4, 'duration': 3.919},
#  {'text': 'llm and the token', 'start': 208.12, 'duration': 5.08},
#  {'text': 'is something that turns', 'start': 210.319, 'duration': 6.601},
#  {'text': 'text for example English text or any',
#   'start': 213.2,
#   'duration': 7.16},
#  {'text': 'text in any language and turns it into a',
#   'start': 216.92,
#   'duration': 6.0},
#  {'text': 'representation that the model can',
#   'start': 220.36,
#   'duration': 5.159},
#  {'text': 'understand so let me execute that right',
#   'start': 222.92,
#   'duration': 5.76},
#  {'text': "now it's going to download and actually",
#   'start': 225.519,
#   'duration': 5.401},
#  {'text': 'let me let me stop', 'start': 228.68, 'duration': 7.0},
#  {'text': "it stop interrupt because like I didn't",
#   'start': 230.92,
#   'duration': 7.72},
#  {'text': 'do one important thing is right now it',
#   'start': 235.68,
#   'duration': 5.04},
#  {'text': 'is downloading', 'start': 238.64, 'duration': 5.4},
#  {'text': 'um the files', 'start': 240.72, 'duration': 6.439},
#  {'text': 'into a particular', 'start': 244.04, 'duration': 7.08},
#  {'text': 'location um this location is specified',
#   'start': 247.159,
#   'duration': 5.28},
#  {'text': 'with a', 'start': 251.12, 'duration': 4.839},
#  {'text': 'variable HF home which we can set this',
#   'start': 252.439,
#   'duration': 6.161},
#  {'text': 'is an environmental variable and by',
#   'start': 255.959,
#   'duration': 7.041},
#  {'text': 'default it uses um cache folder in your',
#   'start': 258.6,
#   'duration': 5.68},
#  {'text': 'home', 'start': 263.0, 'duration': 3.88},
#  {'text': 'directory uh on this machine where I am',
#   'start': 264.28,
#   'duration': 5.68},
#  {'text': 'running this and if you run this in',
#   'start': 266.88,
#   'duration': 5.599},
#  {'text': 'Saturn Cloud you might also have this',
#   'start': 269.96,
#   'duration': 4.36},
#  {'text': 'situation', 'start': 272.479, 'duration': 5.841},
#  {'text': 'um you do not have enough space in your',
#   'start': 274.32,
#   'duration': 5.28},
#  {'text': 'home', 'start': 278.32, 'duration': 4.8},
#  {'text': "directory uh so let's see how much space",
#   'start': 279.6,
#   'duration': 5.72},
#  {'text': 'I have so in my home', 'start': 283.12, 'duration': 5.6},
#  {'text': 'directory I have', 'start': 285.32, 'duration': 7.879},
#  {'text': 'only not so much right not so much',
#   'start': 288.72,
#   'duration': 7.24},
#  {'text': 'space but I have a lot of space in this',
#   'start': 293.199,
#   'duration': 5.961},
#  {'text': 'SL run directory so what we want to do',
#   'start': 295.96,
#   'duration': 6.2},
#  {'text': 'is we want to say hey hien face please',
#   'start': 299.16,
#   'duration': 7.16},
#  {'text': 'use the slash run directory for your',
#   'start': 302.16,
#   'duration': 8.039},
#  {'text': 'stuff right and for that we will use',
#   'start': 306.32,
#   'duration': 5.719},
#  {'text': 'this line of', 'start': 310.199, 'duration': 5.321},
#  {'text': "code I'll include this uh in the",
#   'start': 312.039,
#   'duration': 6.28},
#  {'text': 'beginning I will need to execute to',
#   'start': 315.52,
#   'duration': 6.56},
#  {'text': 'restart the entire', 'start': 318.319, 'duration': 8.0},
#  {'text': 'thing so this is the same as I as if I',
#   'start': 322.08,
#   'duration': 5.72},
#  {'text': 'wrote', 'start': 326.319, 'duration': 4.361},
#  {'text': 'export uh h have', 'start': 327.8, 'duration': 7.679},
#  {'text': 'home and then this value run cache and',
#   'start': 330.68,
#   'duration': 8.04},
#  {'text': 'then run D', 'start': 335.479, 'duration': 3.241},
#  {'text': 'notebook I can also first set this',
#   'start': 339.88,
#   'duration': 5.159},
#  {'text': 'environmental variable and then import',
#   'start': 342.84,
#   'duration': 5.28},
#  {'text': 'the library I it and this Library will',
#   'start': 345.039,
#   'duration': 7.241},
#  {'text': 'pick the the variable from from this',
#   'start': 348.12,
#   'duration': 7.16},
#  {'text': 'location okay now I will just redo',
#   'start': 352.28,
#   'duration': 4.52},
#  {'text': 'everything I did', 'start': 355.28, 'duration': 6.24},
#  {'text': 'previously and we will use um slash run',
#   'start': 356.8,
#   'duration': 8.2},
#  {'text': 'um now SL run directory for downloading',
#   'start': 361.52,
#   'duration': 6.079},
#  {'text': 'the files and now let us execute this',
#   'start': 365.0,
#   'duration': 3.84},
#  {'text': 'one more', 'start': 367.599, 'duration': 4.6},
#  {'text': "time so we're downloading the file uh",
#   'start': 368.84,
#   'duration': 6.079},
#  {'text': "the model files they're pretty large",
#   'start': 372.199,
#   'duration': 5.321},
#  {'text': 'this is not the largest model if we just',
#   'start': 374.919,
#   'duration': 6.441},
#  {'text': 'if we we look up Google plan5 we will',
#   'start': 377.52,
#   'duration': 6.84},
#  {'text': 'see that there are many different',
#   'start': 381.36,
#   'duration': 6.8},
#  {'text': 'models um', 'start': 384.36, 'duration': 7.36},
#  {'text': 'so yeah so this is the list let me also',
#   'start': 388.16,
#   'duration': 6.64},
#  {'text': 'put it in the in', 'start': 391.72, 'duration': 6.28},
#  {'text': "documents um so there's a bunch of them",
#   'start': 394.8,
#   'duration': 6.92},
#  {'text': 'and we use Excel so Excel is something',
#   'start': 398.0,
#   'duration': 6.44},
#  {'text': 'that will fit our GPU if you have a more',
#   'start': 401.72,
#   'duration': 6.199},
#  {'text': 'powerful GPU you can go to you can use a',
#   'start': 404.44,
#   'duration': 5.039},
#  {'text': 'larger version if you have a less',
#   'start': 407.919,
#   'duration': 4.28},
#  {'text': 'powerful GPU or if you have a CPU you',
#   'start': 409.479,
#   'duration': 6.56},
#  {'text': 'can use a smaller', 'start': 412.199, 'duration': 3.84},
#  {'text': 'version okay we have seen this already',
#   'start': 416.16,
#   'duration': 6.319},
#  {'text': "uh it's still being", 'start': 420.479, 'duration': 4.241},
#  {'text': 'downloaded yeah so it will take some',
#   'start': 422.479,
#   'duration': 5.84},
#  {'text': 'time to download the files and to load',
#   'start': 424.72,
#   'duration': 6.879},
#  {'text': 'the files into memory to so right now',
#   'start': 428.319,
#   'duration': 5.761},
#  {'text': "it's downloading the", 'start': 431.599, 'duration': 5.361},
#  {'text': "files um so while it's doing that let's",
#   'start': 434.08,
#   'duration': 6.6},
#  {'text': 'take a look at um what we do so as I',
#   'start': 436.96,
#   'duration': 5.519},
#  {'text': 'mentioned there are two things tokenizer',
#   'start': 440.68,
#   'duration': 5.04},
#  {'text': 'and the model so the tokenizer takes the',
#   'start': 442.479,
#   'duration': 6.28},
#  {'text': 'text and turns it into some', 'start': 445.72, 'duration': 4.72},
#  {'text': 'representation', 'start': 448.759, 'duration': 3.961},
#  {'text': 'and then we feed this representation',
#   'start': 450.44,
#   'duration': 4.56},
#  {'text': 'into the model I think it will be',
#   'start': 452.72,
#   'duration': 5.919},
#  {'text': 'interesting to now look to split this',
#   'start': 455.0,
#   'duration': 7.599},
#  {'text': 'into two parts so first we will look at',
#   'start': 458.639,
#   'duration': 7.0},
#  {'text': 'the input IDs so this is the', 'start': 462.599, 'duration': 7.121},
#  {'text': 'representation of uh this text translate',
#   'start': 465.639,
#   'duration': 6.801},
#  {'text': 'English to German how old are you and',
#   'start': 469.72,
#   'duration': 5.84},
#  {'text': 'then we will actually run the', 'start': 472.44, 'duration': 3.12},
#  {'text': 'model okay so right now what is',
#   'start': 476.24,
#   'duration': 5.959},
#  {'text': 'happening is uh the files uh the model',
#   'start': 479.759,
#   'duration': 6.16},
#  {'text': 'files are already there downloaded and',
#   'start': 482.199,
#   'duration': 8.081},
#  {'text': 'right now we are loading them to',
#   'start': 485.919,
#   'duration': 4.361},
#  {'text': "Memory and while we're doing this I will",
#   'start': 490.919,
#   'duration': 8.041},
#  {'text': "rename this to let's say um huging",
#   'start': 493.72,
#   'duration': 7.039},
#  {'text': 'face', 'start': 498.96, 'duration': 7.799},
#  {'text': 'plan was it f T5 or what was the',
#   'start': 500.759,
#   'duration': 10.64},
#  {'text': 'name F5 yeah okay so it', 'start': 506.759, 'duration': 7.72},
#  {'text': 'finished and so this is the internal',
#   'start': 511.399,
#   'duration': 6.76},
#  {'text': 'representation of this I supect this is',
#   'start': 514.479,
#   'duration': 7.201},
#  {'text': 'an ID for each token so translate is uh',
#   'start': 518.159,
#   'duration': 5.36},
#  {'text': 'this is translate this is English this',
#   'start': 521.68,
#   'duration': 3.44},
#  {'text': 'is two this is', 'start': 523.519, 'duration': 7.361},
#  {'text': 'German um probably colon how old are you',
#   'start': 525.12,
#   'duration': 9.32},
#  {'text': 'question mark end of sentence', 'start': 530.88, 'duration': 8.16},
#  {'text': "maybe probably I don't know uh I assume",
#   'start': 534.44,
#   'duration': 6.68},
#  {'text': 'this is uh this is how it works right so',
#   'start': 539.04,
#   'duration': 5.64},
#  {'text': 'for each toing for each word we have um',
#   'start': 541.12,
#   'duration': 6.159},
#  {'text': "an ID but I'm just", 'start': 544.68, 'duration': 6.32},
#  {'text': 'guessing and then uh yeah actually we',
#   'start': 547.279,
#   'duration': 8.12},
#  {'text': 'get the answer right so well there is a',
#   'start': 551.0,
#   'duration': 7.32},
#  {'text': 'bit of', 'start': 555.399, 'duration': 2.921},
#  {'text': 'um like this is I guess', 'start': 559.0, 'duration': 6.8},
#  {'text': 'technical stuff that the model has uh',
#   'start': 561.64,
#   'duration': 7.48},
#  {'text': 'perhaps we need to filter something but',
#   'start': 565.8,
#   'duration': 6.279},
#  {'text': 'uh so the actually actual thing is so',
#   'start': 569.12,
#   'duration': 5.0},
#  {'text': 'this is what the model is generating so',
#   'start': 572.079,
#   'duration': 4.801},
#  {'text': 'this is the output right again a bunch',
#   'start': 574.12,
#   'duration': 4.44},
#  {'text': 'of um', 'start': 576.88, 'duration': 5.44},
#  {'text': 'ads and then we need to turn this back',
#   'start': 578.56,
#   'duration': 8.2},
#  {'text': 'into text and this is what we use uh',
#   'start': 582.32,
#   'duration': 7.24},
#  {'text': 'with tokenizer and we can see that token',
#   'start': 586.76,
#   'duration': 6.92},
#  {'text': 'zero is this one toker one token one is',
#   'start': 589.56,
#   'duration': 7.04},
#  {'text': 'this one so perhaps if we need to',
#   'start': 593.68,
#   'duration': 6.159},
#  {'text': 'do if we need to filter out this filter',
#   'start': 596.6,
#   'duration': 6.919},
#  {'text': 'out we just remove uh these tokens or do',
#   'start': 599.839,
#   'duration': 7.601},
#  {'text': 'some simple text processing okay so this',
#   'start': 603.519,
#   'duration': 7.081},
#  {'text': "is how we use this model and let's uh",
#   'start': 607.44,
#   'duration': 6.839},
#  {'text': 'put everything together so I will just',
#   'start': 610.6,
#   'duration': 5.96},
#  {'text': 'uh', 'start': 614.279, 'duration': 6.401},
#  {'text': 'um put everything now in one line',
#   'start': 616.56,
#   'duration': 7.36},
#  {'text': 'again like it used to', 'start': 620.68, 'duration': 10.0},
#  {'text': "be and I'll call this result right",
#   'start': 623.92,
#   'duration': 6.76},
#  {'text': 'uh end result is uh the alt z', 'start': 631.32, 'duration': 5.44},
#  {'text': 'z', 'start': 635.24, 'duration': 4.719},
#  {'text': 'okay right so this is how we do it now',
#   'start': 636.76,
#   'duration': 4.24},
#  {'text': 'let', 'start': 639.959, 'duration': 4.801},
#  {'text': 'us change this', 'start': 641.0, 'duration': 7.8},
#  {'text': "part uh I'll take the entire thing here",
#   'start': 644.76,
#   'duration': 8.0},
#  {'text': 'build prompt cuz we will also need to',
#   'start': 648.8,
#   'duration': 5.56},
#  {'text': 'replace the', 'start': 652.76, 'duration': 7.24},
#  {'text': 'prompt um okay llm is this one right so',
#   'start': 654.36,
#   'duration': 8.68},
#  {'text': "I'll put this thing", 'start': 660.0, 'duration': 5.959},
#  {'text': 'here and return', 'start': 663.04, 'duration': 6.479},
#  {'text': 'result return', 'start': 665.959, 'duration': 3.56},
#  {'text': "result so let's", 'start': 670.44, 'duration': 7.519},
#  {'text': 'try this', 'start': 674.839, 'duration': 5.68},
#  {'text': 'rock', 'start': 677.959, 'duration': 5.921},
#  {'text': 'um I just', 'start': 680.519, 'duration': 10.721},
#  {'text': 'discover the course can I still join it',
#   'start': 683.88,
#   'duration': 7.36},
#  {'text': 'um yeah of course we need to replace',
#   'start': 691.56,
#   'duration': 5.36},
#  {'text': "uh yes even if you don't register you're",
#   'start': 697.16,
#   'duration': 6.2},
#  {'text': 'still eligible to submit there um yeah',
#   'start': 699.6,
#   'duration': 6.679},
#  {'text': 'and now probably we need', 'start': 703.36, 'duration': 6.36},
#  {'text': "to make it larger I don't know how to do",
#   'start': 706.279,
#   'duration': 9.68},
#  {'text': 'it uh there is probably Max', 'start': 709.72, 'duration': 6.239},
#  {'text': 'um max token length or something', 'start': 716.0, 'duration': 5.2},
#  {'text': 'something like', 'start': 719.24, 'duration': 6.12},
#  {'text': "I I need to look it up let's see model",
#   'start': 721.2,
#   'duration': 7.56},
#  {'text': 'generate longer', 'start': 725.36, 'duration': 5.24},
#  {'text': 'responses', 'start': 728.76, 'duration': 4.6},
#  {'text': "uh I'll", 'start': 730.6, 'duration': 6.84},
#  {'text': 'generate hi can face', 'start': 733.36, 'duration': 5.68},
#  {'text': 'longer', 'start': 737.44, 'duration': 5.12},
#  {'text': 'responses probably there is um some',
#   'start': 739.04,
#   'duration': 8.64},
#  {'text': 'simple parameter that we can use for',
#   'start': 742.56,
#   'duration': 7.2},
#  {'text': 'that I', 'start': 747.68, 'duration': 5.88},
#  {'text': "don't remember this", 'start': 749.76, 'duration': 3.8},
#  {'text': "perimeter okay I'll check it later for",
#   'start': 756.32,
#   'duration': 7.56},
#  {'text': 'now I see that it', 'start': 760.199, 'duration': 5.241},
#  {'text': 'works', 'start': 763.88, 'duration': 6.48},
#  {'text': 'and perhaps we can tweak The Prompt but',
#   'start': 765.44,
#   'duration': 9.6},
#  {'text': 'like it actually looks quite fine',
#   'start': 770.36,
#   'duration': 8.479},
#  {'text': 'um we can try so usually what helps like',
#   'start': 775.04,
#   'duration': 6.64},
#  {'text': 'this is an uh completion', 'start': 778.839, 'duration': 7.321},
#  {'text': 'model right so usually what helps is',
#   'start': 781.68,
#   'duration': 9.08},
#  {'text': 'um just explicitly say okay this is',
#   'start': 786.16,
#   'duration': 8.359},
#  {'text': 'question this is context and this is',
#   'start': 790.76,
#   'duration': 6.879},
#  {'text': 'answer so I can try to see if this',
#   'start': 794.519,
#   'duration': 5.201},
#  {'text': 'changes', 'start': 797.639, 'duration': 5.841},
#  {'text': "anything um no it's actually but yeah we",
#   'start': 799.72,
#   'duration': 6.96},
#  {'text': 'can experiment with um The Prompt so',
#   'start': 803.48,
#   'duration': 6.919},
#  {'text': 'probably for this one it just works',
#   'start': 806.68,
#   'duration': 6.0},
#  {'text': "um I'll put it on pause now I want to",
#   'start': 810.399,
#   'duration': 4.721},
#  {'text': 'look up the parameter for making longer',
#   'start': 812.68,
#   'duration': 5.12},
#  {'text': "answers and then I'll come", 'start': 815.12, 'duration': 5.76},
#  {'text': 'back yeah of course I use chpt to ask',
#   'start': 817.8,
#   'duration': 3.92},
#  {'text': 'what to', 'start': 820.88, 'duration': 5.24},
#  {'text': 'do and U yeah it told me which', 'start': 821.72, 'duration': 5.76},
#  {'text': 'parameters I need to', 'start': 826.12, 'duration': 5.839},
#  {'text': 'use and I simply will copy these',
#   'start': 827.48,
#   'duration': 7.44},
#  {'text': 'parameters and put them', 'start': 831.959, 'duration': 6.68},
#  {'text': 'here so the parameter I was looking for',
#   'start': 834.92,
#   'duration': 5.8},
#  {'text': 'was max length', 'start': 838.639, 'duration': 4.841},
#  {'text': 'parameter I will also like there is some',
#   'start': 840.72,
#   'duration': 5.799},
#  {'text': 'explanation of parameters which probably',
#   'start': 843.48,
#   'duration': 4.159},
#  {'text': 'I should', 'start': 846.519, 'duration': 5.201},
#  {'text': 'copy I will put this uh', 'start': 847.639, 'duration': 8.721},
#  {'text': 'here and edit it a little bit um so you',
#   'start': 851.72,
#   'duration': 9.28},
#  {'text': 'can read what the they are and let us',
#   'start': 856.36,
#   'duration': 6.52},
#  {'text': 'actually test it but I was looking for',
#   'start': 861.0,
#   'duration': 5.8},
#  {'text': 'this specific max length right so if I',
#   'start': 862.88,
#   'duration': 7.72},
#  {'text': 'do that and three execute', 'start': 866.8, 'duration': 6.0},
#  {'text': 'Rock', 'start': 870.6, 'duration': 4.76},
#  {'text': 'function yeah it says yes even if you',
#   'start': 872.8,
#   'duration': 4.039},
#  {'text': "don't register you're still eligible",
#   'start': 875.36,
#   'duration': 2.68},
#  {'text': 'submit the', 'start': 876.839, 'duration': 5.761},
#  {'text': 'homework and now we have our Rock flow',
#   'start': 878.04,
#   'duration': 5.76},
#  {'text': 'and we', 'start': 882.6, 'duration': 6.0},
#  {'text': 'replaced uh the call to open AI with a',
#   'start': 883.8,
#   'duration': 9.279},
#  {'text': 'local instance of a GPU in particular it',
#   'start': 888.6,
#   'duration': 6.76},
#  {'text': 'was uh flant T5', 'start': 893.079, 'duration': 6.481},
#  {'text': 'Excel and now we can do everything',
#   'start': 895.36,
#   'duration': 7.12},
#  {'text': 'locally without having to call open ey',
#   'start': 899.56,
#   'duration': 6.8},
#  {'text': 'okay uh this flan uh T5 is just one of',
#   'start': 902.48,
#   'duration': 7.12},
#  {'text': 'the possible models there are many other',
#   'start': 906.36,
#   'duration': 5.96},
#  {'text': 'models and in this video I want to',
#   'start': 909.6,
#   'duration': 5.0},
#  {'text': 'explore another model from Microsoft',
#   'start': 912.32,
#   'duration': 7.639},
#  {'text': 'called P3 so see you soon', 'start': 914.6, 'duration': 5.359}]

# %%
import pickle
#Load Dictionary
with open('transcripts_timestamps.pkl', 'rb') as infile:
    timestamp_transcripts = pickle.load(infile)
with open('transcripts_timestamps_links.pkl', 'rb') as infile:
    link_transcripts =pickle.load(infile)
with open('transcripts.pkl', 'rb') as infile:
    full_transcripts = pickle.load(infile)

# %%
full_transcripts
# link_transcripts[0]
# Out:
# {'LLM Zoomcamp 1.1 - Introduction to LLM and RAG': "hi everyone Welcome to our course this is our first module for first unit so in this course the course is called llm Zoom camp in this course we will learn about practical applications of llm and in particular we will focus our attention on rack retrieval a generation I'll shortly talk about these variations what they mean um and what we exactly will do and I want to start first with explaining the problem we are going to use uh to solve throughout the course um so this will be our running problem and in our community in data do club we have multiple courses so this llm Zoom Camp is our fifth course and usually in our courses we have frequently asked questions so there are questions that uh there are no answers in the videos or answers are not uh easy to find and we have these documents I'll quickly open one of them and in these documents we have frequently asked questions so the format is there is a section then there's a question then there is an answer and this is like that question answer question answer and we have quite quite a few of them so in this particular document for the data engineering Zoom camp we have 321 page of such answers and typically we ask the students to uh use this document so before they uh go to slack to the channel to the group to the course channel uh we ask them to check this document first before they ask a question and of course um most of the questions they have the students have they will find here but the problem is that it's not super easy to find right so there are 321 questions like how do you actually find the information you need here so this is not trial that's why we will use the data from uh these FAQs from the three FAQs from the three courses and we will beat a b we will build a report a Q&A system that given a question from a potential student will use the documents the fq documents uh these particular documents to answer questions from the students so this is what we are going to build at end it will be a simple form this is how I see right now we have not buil it yet it will be a simple form where you put an answer a question and get back answer so how we are going to do this we are going to to use llms and tracks so what they are and this is exactly what we are going to talk about in this module so now we will talk about LMS we'll talk about rack what the rack is and what exactly we are going to cover um well what exactly you will learn in the course um and what you will build so let's start so and we will start with what llms are so llms or llm it it stands for um large language model LGE language model uh and we can start with just language model so language models are things that predict the next token the next word based on the words you have typed so far or you have so far in your document so imagine your phone right so you open WhatsApp and you want to text somebody let's say you want to text your body your friend so you start typing how space i space and the phone your phone will typically suggest you as the next logical word because typically what you type is how are you so it recognizes how are so logically the next word be you right or how are there maybe you want to ask how are the things right so it suggests you commonly common words that go after how are and um also on your phone this is personalized to you and your phones use language models for that so typically it's something simple like na base uh that just predicts the SEC the next word based on what you typed of far so these are just simple or we can call them small language models so they don't have a lot of parameters um they're quite simple they're also quite um how to say stupid let's say because stupid compared to large language models so lot usual simple language models do their job fine but large large language models U there's a reason they call large because they are huge so they have a lot of param they have billions and billions and billions of pa ...
#  'LLM Zoomcamp 1.2 - Configuring Your Environment': "hi everyone in this video I want to show you how to configure your environment in this particular video I want to use GitHub codes spaces to show how to configure it but you don't have to use it you can just follow along the video and do everything you need on your local machine I will not show how to install Docker you will need to do it yourself because Cod spaces already has Docker and we will focus on installing uh the libraries we need for this particular model or you can like you again as I said you don't have to use cod spaces it's a very convenient tool but you can also for this model you can use G collab Google collab you can use C Cloud uh you can use any other notebook provider like Sage maker or you can just run things locally for the uh second module we will need a GPU right now we don't need your GPU for the second module we will so if you have an access to a machine with GPU it's good you should use that if you don't uh then this is something we will talk about in the in the next module right now back to Cod spaces I will show you how to set up a simple uh environment from scratch and it's free so you should go to your GitHub account create a new repository uh give it some name so I'll call it llm Zoom camp and um it should be public because uh like you will um commit your notebooks uh your homeworks here um and then you will need to share the link to the homework in the answers uh in the answer for so make it private and then uh so license we don't care about the license G ignore should be python so let's create a repository and once the rep is created we click on code and there are two tabs Here Local and code spaces I just click on create a code space online right now it will start Visual Studio code in a browser so it is preparing the environment uh we don't want to use the browser so I already have Visual Studio desktop um on my computer you should also have it if you want to follow uh along uh this tutorial again you don't have to do this if you already have the tools we're going to install later you should be fine so now let me open it uh on Visual Studio code desktop so I clicked here and I click on open inv this code desktop and right now Visual Studio code if it's the first time you uh run Cod spaces it should after some time should ask you to to install an extension for COD spaces if it doesn't you will need to do this manually you go to extensions and you type code spaces here yeah so this one you will need to install it I already have it so I don't need to install it and actually we already have a code space enabled in accessible in our Visual Studio code desktop and I just pressed contrl Tilda to open the command line and here we have already have Docker can run hello world so Docker Docker compose uh are already here and we have Python and um I'll show you two ways of preparing the environment the first uh way would be just using the python that we already have here we will need to install the libraries we need and then in the second part of the video I'll show you how to install an aond with anakonda you don't need to install any libraries you can just download in AA and that's all you need so uh for installing libraries we'll use peep in in install and then there's a bunch of libraries we need to install tqdm which is a progress manager it's very convenient uh then uh well we will not need tqdm actually for this particular module we will need it later uh then we will need jupyter notebook I'll specify the version uh the version will will be 7.1.2 then we will need open ey to speak to uh the open AI API and also we will need um elastic search so Arch right at the end as I said we will first we will use a simple toy search engine but then at the end of the module we will replace it with elastic search and so that's why we need to install it um I don't know if we need to install anything else so also I think P learn uh yeah and pandas so that's J ...
#  'LLM Zoomcamp 1.3 - Retrieval and Search': "welcome back in this video we are going to talk about retrieval and I want to start with talking again about the rock framework remember in the r framework we have two components the database and llm so here for the database we will use a simple SE search engine uh the search engine that we implemented as a in one of the pre courses uh pre-course workshops and if you go to the uh course repo you can see the workshop here implementing a search engine there's a video that that you can hold follow along and there is a GitHub rep so in that Workshop we implemented a search engine it was a very simple inmemory search engine it's not production ready it was just for illustrating how search engines Works work and right now we are going to use this simple search engine and later later in the model we will replace it with another one uh with elastic search but here I just want to illustrate the principle so right now what we're going to do is we're going to take this search engine and take the data from the FAQ documents and put the data to the search engine and perform a simple search and later we will use the results to put I can just open it here we'll get the results put them into an nlm and we will get answers to our questions so this is the first step and we are going to use this um so there is an an implementation that we're going to use this is this minan search this is the python file that implements the the search functionality so I'm going to get the r uh implementation um I just want to download the file the the r python file I just want to download it it's not people install able so I just download the file and use it as a as a package so I already have it um I already have um my Jupiter running here I'll start a new notebook I will call it we can call it Ro intro for example and the first step here I will download uh this uh search engine the this implementation using W get command and now I can just import it import main search so this is Library uh we implemented it took a bit of time for some reasons um so this is the search engine we implemented and right now we are going to get the fq documents the fq documents um I already passed them so they are in adjacent form it look like that looks like that so we have for each course we have adjacent object and inside the Json object we have different documents like the question the section of the document and the text is the answer to the question if you're wondering how exactly I extracted these documents there is another uh another IPython notebook that uh you can see how I did that so this code I used for extracting the documents so this is something you can use for your own projects later if you want if you have a also a Google Document which you want to use for extracting the data this is what you can use I will not go into details of how exactly it works although if there's a lot of interest maybe I'll record another video of how it works but for now we just get the dat this Json file and we will need to load this data and we will need to put it into our search engine so for that I'll import the Json built-in library and I will open the the documents yeah documents oops um so we open it in read text mode as F in so this is the anation I usually use fcor in is file input so we open file for reading and then doc I'll call it DOC ra is Json Lo F so this is um this is document maybe I should have not printed it um and the structure is as I said for each of the courses we have like nested structure with documents now I want to put everything into um so what I want to have is to get rid of this nestedness so I just want to have a list with dictionaries a list with documents so I want to create um so keep this as this just add another field course and use this data gen camp or other courses so let me call it docment um so this will contain the result and we just go for course in document s then for I Doc in course we can just go say ...
#  'LLM Zoomcamp 1.4 - Generating Answers with OpenAI GPT 4 0': "welcome back in this video we will talk about generation so previously we indexed our documents with a search engine now we can perform a search using a user user query and let me just quickly show you what we built so far so we have a query the course has already started can I still enroll and from our knowledge base we can retrieve the answers right now what we want to do is take this uh this potential this document from our knowledge base the documents that may or may not contain the answer we want to put them into an llm as a context to the question that the user has asked right so we will need now uh form a prompt and send it to open AI or some other llm so in this in this particular video we will use openi as an as an llm we'll use DPT 40 the newest one which is also reasonably fast and quite cheap compared to G pt4 so this is the llm we are going to use and the database is this mean search the toy search engine implementation um so I should already have configured um I have already configured the key so now I can just do for open AI import open AI so this is our client uh open AI so I don't don't need to do anything cuz I you put the key in the environmental variable like I showed in the preparing the configuration video and now we will use again chat completion API chat completion API and we will use uh GPT 40 and um so the pro the the question we will use is actually the same so this Q the course already started can I still enroll so this is what we will put right now for now in messages um so roll user content q and yeah we will put this to response and do I need to put um maybe minus here so it took a bit of time now let's see what response is and we'll look at choices then message content right so this is um the response again it just gives some stuff like very generic uh answer now we want to get this content context the answers we retrieved from the knowledge base and put it in the prompt uh so hopefully now our llm will include the the content with the context and give a better answer so our prompt uh can look like that prompt um I'll call Prompt template um so we will need to explain it what we do and usually a good practice uh for prompt engineering is we need to give it a rle um so we can say you're a course teaching assistant so this is the role that we give we assign into nlm and usually we need to do this for more advanced llms like gbt 4 gbt 3.5 uh for some smaller llms maybe we don't necessarily need that um so and this is U um it's more like Art and Science because you just need to do a lot of experimentation and see what works best for you um so first it's just Tri an error but then later later in the course we will also talk about different evaluation metrics so you will actually be able to numerically evaluate the goodness uh how well your prompt performs right now we'll just uh put this so your course teaching assistant answer the question and who will give the question here um question I don't remember with templates and python I think it's just one one CBR so answer the question based on the content and we will also provide content context context context um so we'll have context here and we can also say if the context doesn't have the answer um or like let me say it use only the facts from the context context when answering the the question and we can also add uh add L breaks if the context doesn't contain the answer contain contain the answer um output no something like this so we have a prompt template um I don't think we need to uh put anything else um let's add from the F data database we can play with this forever ever but this is just a good template right so this is a template and now we can add the question from the user and also the context let's build the context so I'll um start with an empty string and we will just iterate over um our documents for Doc in Posite results think was results right so now we just need to iterat ...
#  'LLM Zoomcamp 1.4.2 - Exploring Alternatives to OpenAI': "a very common question people I see people ask in slack is if we can use anything else apart from open ey yes and we will cover open source models in module two but there are other services that we can use instead of open AI that provide very similar kind of uh service like an API too that you don't need to host yourself you can just send a prompt and get back a response very similar to open Ai and I want in this video to talk about Alternatives and I want to ask you to provide a list of different Alternatives I already saw some in chat in slack and let's build a list of Alternatives together and for that I created a markdown page in our uh first module and this is uh open AI Alternatives I already added one mistal AI in mistal um yeah I need to add HTTP but let me just I'll fix that but if you go to mistal there is this La platform sorry for my French and you can sign up for a free trial they will give you like five EUR uh on your plan and there are many many other services like mistal that we can also use instead of open so if for some reasons you don't want to sign out for uh to create an account with open AI or there are Ser services that provide some free credit credit that you can use uh during the course um meaning that you will be able to just do the course for free let's build a list here uh send your pool requests and you're free to explore and try other things um I've already seen in slack uh some other platform I don't remember the name and and somebody said that um I think it was aradi uh he said that you can also use for example a yes uh it was Bedrock I think the service is called they have a bunch of llms too and then it's fairly easy to find online um Ed yes credits like $25 for example um yeah so let's build a list like that and we don't have to restrict ourselves to just open a",
#  'LLM Zoomcamp 1.5 - The RAG Flow Cleaning and Modularizing Code': "welcome back in this video I want to show you how to clean the code we wrot so far make it modular make it easier to use and then replace different components later as we go along the course so this is what we this is the rec framework we send a query to our index uh to our search which is a Min search implementation then we build the prompt send it to an llm in our case GPT 4 40 and then get the answer and this is the implementation that we made in the last couple of videos so here we index everything we retrieve the results uh we send we built the prompt and then we send the prompt to open a so now I want to put everything together so first the first function I want to clean it make it more modular put everything together and break it down into simple functions so clean uh the code we have wrot so far so I'll first start with a function called search and here we will have query um so here I will basically take this piece of code and put it here so this is what we have and I'll just return the results and of course here instead of Q we have query and let me just quickly check that it works how do I run Kafka and then it retrieves some questions about Kafka and here yeah uh we limit our answers only to dat engineering zom Camp course so this is our search function then the next function is um we want to turn let make sure put it back so we want to turn this documents uh results we want to turn these documents into a prompt so we have we have some code here for that I'll just put it together [Music] and over here they built prompt so here we have we need to have a query and we need to have the context right so we have the prom plate we have the um let's actually call it search results and then yeah the content then we have the prompt and this is what we return prompt let's see if it works so I'll put this into query query so this one works this one query and search results so we have the The Prompt prompt and now we need to to put this prompt let it here I'll keep everything in one line now let me also put the logic for invoking the GPT I'll clean up a little bit uh so we don't need this anymore um so I'll take this one so this will be llm so llm Gets In The Prompt and gives back some answer so this is what we do so now answer LM so we get in the user query we perform the search we build a prompt from the search results and we get the answer from the LM and this is nothing else but an an implementation of this flow so now each of the steps we expressed in functions and let us try to execute that so what does answer contain yeah well probably there is no answer to that question uh but um let's try how do I enroll the course just started how do I enroll okay I don't know maybe let's play with this a little bit I'll change the prompt slightly okay yeah well it's not correct I don't know we probably need to deac let's see if the search results actually contain um the questions what can I do before the course can I fold the course after it finishes yeah the course already started can I enroll yeah good it works well as you see there is still some room for improvement so probably if we played with this and added a little bit more uh results we can actually do that right now by changing the number of results to 10 um and what I wanted to ask like how do I run Kafka I don't understand yeah let me see I think we have a we have made a mistake somewhere results uh yeah I think this is the error this is the problem so query should be not q but query context is context and let us execute things one more time yeah well now the the the the mystery solved I was just not careful we can we can play with this parameters to so let me see if five answers is actually enough yeah this is enough so now what we can do is put everything into a simple function that we can call Ro and then now it's even simpler we just do rock query and then it should give us the answers uh the core has a ...
#  'LLM Zoomcamp 1.6 - Search with Elasticsearch': "welcome back this is llm zoom camp and in this video we are going to replace the toy search engine we used previously with elastic search quick recap of what we have done so far we have a knowledge base which we index with a small uh Library search engine and now with user query we can retrieve the relevant document build the prompt and send this prompt to nlm and TM will give us an answer and we already have the code for that so this is what we implemented previously and now and one of these uh things like search uses a toy search engine that we implemented in a precourse workshop now we want to replace it with a a proper search system with elastic search uh but why did we actually use this toy search engine in the first place you may wonder and it's because later in the course we might use tools uh like sat Cloud where it's uh not easy to run elastic search so having something that runs in memory and gives good results is um a good thing plus we wanted to see how to implement the search engine so this is why we use it previously but now let's replace it with something real life something you will actually uh probably use in practice okay so this is the thing we want to replace the search with something else so let's do that first of all we want to run elastic search right now I'm in my code spaces and I have this command for running elastic search in Docker so this is running elastic search of this version I don't know if it's the most recent or not now I'll open a new terminal and I will execute this comment so I just copy it here so elastic search will run on these two parts and uh now it will download the docker image and start elastic search and okay I don't [Music] know yeah whatever we just need to check that our ports the port that we need are forwarded and these are the two ports that we actually care about so we will use uh this port 9,200 so I'll create another uh terminal and execute a simple HTTP get request uh to Local Host uh this so this is the URL I don't know why I cut it it's Local Host uh 92000 this is where elastic search is running and we see a response which means that it works and actually we don't really care about uh this port being forward to our local machine to our host machine because we are going to use elastic search only within Cod spaces but anyways it forwards it okay and now we can see that it works so now let us um first we will index these documents that we have here let me remind you these are the documents we have so now we want to index them with elastic search and later use this for searching the thing about elastic search um is that it's actually persistent meaning that unlike this toy search engine uh when our machine stops when we finish this Jupiter notebook process we need to basically next time we start we need to rebuild the whole index but when it comes to elastic search it saves all the data on disk next time we start elastic search it will have all the data we need so we will not need to ex to executed of course it depends on how exactly we run it so we might need to do volume Ming for that this is outside of the scope for this course if you want to learn Docker in more detail you can check our data engineering course module one where we talk about Docker in a lot of detail right now let us see how we can use it from uh from our Jupiter so we want to replace this line here so let's do that first I'll import elastic search um so we should have installed it so from elastic search import elastic search I hope I typed it correctly elastic search yeah so I did from the second attempt so now let's create elastic search client which can be elastic search and then the URL which in our case HTTP Local Host uh 92 0 if you deploy elastic search somewhere in the cloud uh then you can just use the the Euro you get but um yeah this is the local deployment and we can check that things work by executing this info function so this is the same ...
#  'LLM Zoomcamp 2.1 - Open Source LLMs': "welcome back this is module two of llm Zoom camp and in this module we are going to explore alternatives to open Ai and in particular we're going to talk about open source llms that we can host ourselves on our own computers or somewhere but we have full control over the model we can execute this model on our Hardware so we will explore different options of different models there are a lot of open source models actually and I asked chbt what are the well-known ones there are a lot more and actually like even though it's a I asked for well-known ones I have not heard about many of them so there are I know hundreds if not thousands of them already available so here is the list um maybe you have heard you must have heard llama already so this is a model from meta from Facebook um and in this module I think we will we will use this flan T5 or just T5 I don't remember but like one of those developed by Google maybe you've heard about mistal and they also have an API that you can use we talked about that in the previous moduel so there are many of them and what we are going to cover in this module is how do we take this mod models and how we want to run it running these models usually requires a GPU so we will need a proper environment this is Will proper environment for that this is what we will also talk about so what we will do is uh if you remember we talked about this rack flow so what we're going to do is we're going to see how we can replace this box with something else and this will be the focus of this model and in particular we will see how to set up an environment and we will see how to use different LMS okay I think uh so this is where we talk about flan T5 I think so we're going to cover we will look at different modules uh with different models how to run them and then how to access uh models from hin hgin face hub and think like things like that so uh have fun this is going to be an interesting model and in the next model we will see how to get a notebook with the GPU where you can run uh all these models see you soon",
#  'LLM Zoomcamp 2.2  - Using SaturnCloud for GPU Notebooks': "welcome back this is Alm Zoom camp and in this video we are going to see how to use saton cloud to get a machine a notebook with a GPU cuz for open source llms most of them require a GPU um and sat Cloud can give us an environment where we can do this it's only it's one of the possible options you can use uh for example Google collab then in Google Cloud platform there is something you can get a machine on AWS I think with a s maker you can get a notebook with um a GPU there are many many options in this video we will look at using Saturn Cloud so here I have Saturn Cloud um so what we need to do is log in if you already have an account if you do not have an account you have two options so if you're watching this uh before this uh module actually started you can go and fill in the form in our course management platform and then you will get access to the platform with already some extra GP hours if you're watching later you can click on get a technical demo and then mention that you are from uh I am a student uh or I'm a participant oh from LM Zoom Camp something like that right so just mention that you're coming from the course uh and then you should get the demo okay so I already have an account so I'll just log in um I think I should uh be able to do it with Google and now I have access to the platform um I will show you how to create a notebook in C Cloud before that I want to show you a few other things so first uh of all is secrets so this is where we can add tokens like open AI token or um huging face token right so this is how you do this so you can say that this is hugen face token and then it's huging face blah blah right so this is where you put your token um yeah so this is how you create um Secrets then one other thing is um setting up kit access so you go to the users and you have this public uh SSH Keys uh section right and I will replace the this after this video but you can go to GitHub up and I will not show it here but basically you can take this key put to GitHub and then you will have access from the the machines you create here on sou Cloud to get okay so now the interesting part is creating a notebook so it will be new notebook server I will also uh create like later if you watch this course uh later you can go check uh data do Club llm Zoom cam Southern Cloud so we already have here a starter notebook I also want to have here a button uh lounge with saton Cloud I'll put a link here also let me add a link to sat sat Cloud here okay and this is actually the notebook we are going to use uh the starter code and um yeah here let me call it LM Zoom cam HP and this is the only option I think I have and then here we choose a Saturn python llm and this is an okay version uh so I know that southern Cloud team right now is working on creating a new image so later if you see a new version here um just use a newer version for now we will use this one and now we need to install extra packages in particular we need to run this command so we need to install the latest version of the Transformers Library accelerator library and bits and bytes Library I will copy this thing and put it here and this is what SAT Cloud will execute when it starts and I will also add our G repo and this one llm zom Camp sou Cloud uh this one okay so I don't don't think I need to do anything else yeah let's just start it did it click yeah I did not okay and now we need to go to secrets and roles to add the token we previously created in case you need but yeah this is how we do it and we just click Start and it's going to take some time so I will put it on pause and so let me check time so it's 8 uh 53 now so I'll be back when it's ready well I was away so I don't know when it actually finished uh preparing I checked it a few times most of the time it spent uh pulling the image but now it's uh it was roughly 9 minutes so I I think it was much faster than that okay anyways it's ready  ...
#  'LLM Zoomcamp 2.3 - HuggingFace and Google FLAN T5': "welcome back and in this video we are going to run our first llm open source llm this will be an llm from Google and we will use a huging face library for that um and uh if you words about huging face so they have um so Hing face is the way I see it this is a place for that hosts model so you can upload any model there and this is kind of a model repository in a way so if you want to uh find a model usually you go there and many companies uh like for example Google publish their models on Hing face so there's a place called Kagen face Hub and this is the place for models and we can see that um like right now on their website and we see that there are trending models and I think um this quen 2 this is an llm and they have like not it's not only llm there are many different models and this what you have chpt 40 I don't know what is that it's probably okay I will not attempt to uh go there the important thing to know that uh the library we will use will actually go to hgen face Hub to fetch um the model files okay so we have that and we install actually these transformers this is a library by hgen phase and when we use Transformers and when we download models using trans the Transformers Library we actually go to huging face to fetch this library to to fetch these models and um there we will use this model Google flan T5 XL so this will be the first model and right now I am just going to Google this model and this is the first result so we are now in on hgen face in the hgen face Hub on the model description of um this model right and so this link describes the model I will put it now here in the link in in the links session you can check it out later and the interesting part usually this is like rme or GitHub projects except this rme is for models and usually there is a very good um examples of how you can run the model so there is like how you run it on a CPU we have a GPU machine or at least I'm showing it on the GPU machine you can try it on CPU but usually it takes some time to do that and I just copy this piece of code and I will put it here so I'll split it into multiple blocks so first we do the import and here we need to import two things the generator and tokenizer so the difference between them well it's actually kind of self-explanatory if you look at the code so there is one thing that is in the model this is the actual model the actual llm and the token is something that turns text for example English text or any text in any language and turns it into a representation that the model can understand so let me execute that right now it's going to download and actually let me let me stop it stop interrupt because like I didn't do one important thing is right now it is downloading um the files into a particular location um this location is specified with a variable HF home which we can set this is an environmental variable and by default it uses um cache folder in your home directory uh on this machine where I am running this and if you run this in Saturn Cloud you might also have this situation um you do not have enough space in your home directory uh so let's see how much space I have so in my home directory I have only not so much right not so much space but I have a lot of space in this SL run directory so what we want to do is we want to say hey hien face please use the slash run directory for your stuff right and for that we will use this line of code I'll include this uh in the beginning I will need to execute to restart the entire thing so this is the same as I as if I wrote export uh h have home and then this value run cache and then run D notebook I can also first set this environmental variable and then import the library I it and this Library will pick the the variable from from this location okay now I will just redo everything I did previously and we will use um slash run um now SL run directory for downloading the files and now let us execute this one  ...
#  'LLM Zoomcamp 2.4 - Phi 3 Mini': "welcome back in this video we are going to try another open source model also available on haging face Hub in the previous video we already used uh our first open source llm model on a GPU it was Google's model flan T5 XL and now we will use a model from Microsoft this model is called fe3 uh this is rather new model and um I think uh this um plant T5 is an older one and what we will do is just again look it up and Google the first page at least in my search is again a page on hgen phas and here we see the description so I think they have like different um uh again different sizes like with uh other models uh so this one is a small one so it doesn't have a lot of um parameters that's why I think it's called mini and uh probably there are more details if we check this block um yeah you can check it out so we saw this mini and small uh the small one should still fit the GPU that we have although not true but usually 7B or less fits a GPU like the one we have and by the way I don't think we actually discussed that so maybe we can quickly check so I'm right now I'm going to open a terminal so this machine is machine a machine with a GPU and I'm going to do Nvidia SMI and this lets us tells us what kind of GPU we have so in our GPU we have U this amount of memory and um it's like almost 16 like 15 gigs um and usually oops it's a wrong link um so usually these 7B models fit on such gpus but they might not so depending on on what kind of GPU you have you might have to try smaller or you can try larger Gus and I think um so right now what I also sometimes do is just to watch this so then we can see like a dashboard and what we also need to do is we need to stop shut down the previous model so it doesn't take any GPU even though like it was actually using zero megabytes of memory I don't know why but typically when you start running a model um I I be honest like I just started this instance of jupter notebook but if you contined uh from the old instance probably you would have seen something else like there is a process that takes the GPU and then you see that more RAM more memory of GPU is used so that's why I stopped it so now the memory is free and now I'm going to duplicate it and we will call it I'll rename it so I'll use it um P3 right so let me run it again and I will run it only up to this point so I'll create empty else here so what I did is I just pressed B and then I will remove this one and where is this uh yeah we're going to close it so we have this um model uh read me file from this V3 and I think we have an example here so this is an example again like last time I'm just going to copy it and and then execute it one line by line by line I don't think we need this one um okay so I'll also set it here so this one just sets the random seat to zero so our what we do is reproducible and now we download the F3 model and the tokenizer for the model okay it's downloading this right now and I think if we compare it with this flant T5 I think T3 is actually smaller um yeah so this one is 10 gigs let's see how large is P3 so we have the first uh part is yeah so it's like five plus it's like 7 gigs versus um like 11 gigs I guess okay so let me close it um so the way we use it is as you see the interface is slightly different so actually here we have more like a chatbot interface so previously it was like a completion interface so we had a prompt and then the task of anlm was to complete this but here it looks like we actually have a chat um so we have a bunch of messages and then we send this to pipeline pipeline I think combines um model and tokenizer into one so let me create let me just put it in a separate so we create a pipeline which combines both and what we have here is messages some parameters and it this is similar to what we did previously we passed some parameters remember I needed to I think I still have it here so yeah I needed to talk to chpt to learn about parameters so this model al ...
#  'LLM Zoomcamp 2.5 - Mistral-7B and HuggingFace Hub Authentication': "hi welcome back in we in this module we are looking at open source llms we have already looked at Google's fl5 we have looked at uh Microsoft's F3 and now we're looking at Mistral 7B model so again like previously I just copy it go to Google paste it and end up on the card page so let me add the link here yeah I think it's already here and you can see that we don't actually have a lot of information here uh meaning like there is some information but previously we saw that there is always a piece of code an example of how to use a model here we don't have this information right so probably we can just follow the same uh approach like here with um like creating a model creating tokenizer luckily we don't need to of course we can also ask Char PT it probably knows but also actually the the way I found out about this particular model is I Googled uh hugging hugging face where can I type llm models and yeah I visit it often so this is the the link I wanted to share with you and in actually in day tutorial they start with uh this mistal model so let us also let us take the code from here and I will create a copy so first I will shut down and actually like if you watch this after watching after after watching the previous video you can see that F3 takes this amount of memory so 8 gigs uh let's stop both of them 532 and now yeah zero memory I will now create copy again and we will call this um mral 7 B again execute so this one I don't execute and let us take this piece of code and also we will need the tokenizer right so I will put UTS here separately and then here we have um a model and here we have a tokenizer and I will put model inputs here um okay so let us execute that and we see that it doesn't work so there is client error unauthorized uh access so actually we cannot access this model and the reason for that is this model requires us to accept the agreement I have already accepted it but if you visit it for the first time you actually need to be logged in and you will see um like an an aru an agreement which you will need to accept and only then you can use the model so unlike the previous two models here you actually need to say that uh you will not use it for something that is not intended by the by the developers okay so you will need to accept that and it means that you will need to somehow get access an authorized access to the model so the way you do it you need to have an account in hgen face then you go to settings and then you go to access tokens and then you create a new token so let's call it course uh LM course um yeah read access generate token so this is the token of course you should not show it to anyone I will not show I will disable this token after recording this video and we will now just remember this token typically we would put this Tok actually in an environmental variable uh I will just pretend we actually did this I'll call it HF H can face token and put it here so we kind of did this outside we can pretend that we did this outside of jupyter notebook um like for example if you use S Cloud you can put it to to Secrets if you use um Google collab you also have collab Secrets there um so typically if you have some hosted notebook solution you have a secret management component or if you run it locally you just put this into your terminal or use a end file whatever but typically you don't put it in um code like I do here and um I will also now yeah get it so I think um the code is uh from hugging face Hub import login yeah um we call this login yeah we need to provide um this token token and this yeah so token is valid your token has been saved login successful okay so now we can access the model CU I already accepted the agreement if you have not accepted the agreement you would see another error and while when it downloads um so we already have an example so while it's downloading let us check the the rest of the tutorial so this is ...
# ...
#  'LLM Zoomcamp 7.3 - RAG evaluation': "hey welcome back in this series of videos we're doing an nend to end project similar to what we did in the course but a different one so which is about building a fitness assistant so so far we have covered uh these three first three criterias so now I want to talk I want to cover this reculation which will be like in the previous cases mostly copy and paste from the course materials um so let me now go to monitoring and I want to find this offline regulation notebook and copy paste things from there so I already have the ground roof data set let me actually call It Rock evaluation and what I want to have here uh yeah I'll just continue using the same uh approach as previously I just want to know how well it works right so this is theflow okay sign similarity metric so I just want to I don't know if I should use cosign similarity um I'll just use llm as a judge so for S similarity uh it's a good metric I should implement it too uh but now I need to install an extra Library I don't want to do it right now so what I'll do instead is um and actually like I'm not really sure if I can do cosign similarity here cuz I don't have a reference uh yeah I don't have a reference answer here so probably the only thing we can do right now is as a judge of course when we start running the um when we start running the application and users start giving up votes and down VES we can use up votes as a reference uh answers right but we don't have this data yet so the only thing we can do is actually using this llm as a judge and I will now so here we don't have the original answer right we only have the question and the generated answer so we need to take this thing uh you're an expert relator for a rock system your task is to analyze the relevance of the generator answer to the given question based on the relevance of the generate answer you will classify it as yeah okay looks uh good so now uh I won't do it for a sample I can just do it for the entire thing we only have um let's see 1,000 like with GPT 4 or mini it's not only fast but also pretty cheap so I can just do it for the entire thing um but also taking a sample is fine right so let's see how a prompt might look like for um so the record would be ground truth [Music] zero and yeah answer LM of course yeah we need to also give an llm answer question we have the question we don't have to answer right um question will be record question and then the [Music] answer answer LM will be Rock so what I'll do is I'll here the question then we send it to Rock Let's see what the answer the starting position for doing pushup is to okay so question is question answer LM is answer LM so let's see what the PR is so this is the prompt and again we use LM for this prompt and then it says it's a relevant answer okay so now we will use judge to actually evaluate all our answers and we should have here this thing and this is actually not complete let me at Ground Ruth and I will just do this thing and we will need to actually I want to append U so I want to append U the uh record from the ground roof um so it will be record ID right then um I want to append let me just append the entire record then append the answer from the LM and append the evaluation this should be prompt to so let me see if I forget anything uh I only forgot parsing and let me do it like that so record ID if ID in evaluations then we don't redo it and I want to do it just in case if something is wrong right so for example the Jason is not possible then I just hit uh shift enter one more time and then I redo the thing and then aeration ID is um let me make it a little bit more interesting so I'll just have ID here which is ID question which is question then answer LM LM and then evaluation which will be evoluation okay so I think it looks correct so we iterate over the ground proof data set um yeah let's let's just see yeah so here I did not copy this thing properly so let me just do that okay let's  ...
#  'LLM Zoomcamp 7.4 - Interface and ingestion pipeline': "hi everyone welcome back in this series of videos we are implementing an NN project uh this project is a fitness assistant uh we what we have done was already well quite a lot so we generated the data set we implemented track flow we wrote the problem problem description and dation retal Elation and track evalation now I want to tackle these two parts interface and ingestion pipeline because we don't use a real database our inje pipeline will be simplified so I'll go to an automated ingestion with a python script which will happen at the same time uh when the interface starts right so if you use real database then your inje pipeline and interface would be separate things uh and um will be a separate script that does the ingestion and then a separate uh application that does the interface could be stream lead or Jango or or fast API so I want to tackle here both of them and at the beginning I thought we already covered stream lead let's use flask streamlet or any UI is uh usually better at least in the sense that it's more visual uh but since I decided to go with flask we can do that too it will be just more common line less visual um but then nobody um nothing prevents us from building an UI on top of the API so let's do that what I'll do now is I'll go to uh this uh notebook that we wrote already um that we created already I still don't know why I don't have syntax highlight for some reasons it doesn't work for me but anyways so this small part is the inje and uh this part is our Rock FL right so now I need to expert it save it as a python file and then create a bunch of scripts so I'll I'll actually use common line right now for that so um I'll go to notebook and do um so first of all I want to create um I'll create uh a package for that I'll call it Fitness assistant so this will contain all the code right now I will convert and front I'll convert The Notebook Jupiter NB convert to script I think uh Rock test I hope I get it right I don't remember if I should write to script or to python um yeah it works so now I will just take this script and move here and also we need me search I'll put here too so and now um I'll create two files uh first one in just pi and second one is um appp now so these names are arbitrary you don't have to use the same names um so this will be our inje script so copy it and just and notice that we actually need uh need the data set so when we start the script we need to make sure that the data set is always with us because this is um how our injection works so when we start the application it loads the entire script in memory so it means that our data set needs to be with us all the time um so I'm cleaning a little bit and I don't need that CL and then I'll just call it he okay um lot data uh and like this stuff will go here or loot index and there will be return index um let's use path data path which by default will be this one okay so this should do uh let me format it a little bit okay cool so this will be our injection script of of course like if we use a proper database it will be more complex and um I think what we did uh in the course llm um I think here in app so we have our generate data uh no not that one um TB so I think that was kind of our ingestion script in the sense that um wait where did we actually create um rep yeah so here um we have this uh thing that puts the data in elastic SE sets up the database and all that stuff so that was our sort of inje script which we run prior to running our application and like when we do it in Mage this is also what we run prior to running application we create the index we ingest all the data um so we can use Mage I'll just use or prefect or like whatever uh orchestrator you want here I'll just rely on a simple python script um and I just wanted to add a note that right now this will give two points um uh or a simple python script but in the future editions we actually might revisit um thi ...
#  'LLM Zoomcamp 7.5 - Monitoring and containerization': "hi everyone welcome back in this series of videos we are doing an end to end project for the llm zomom course and uh we in this video we want to cover no we want to cover actually monitoring and con containerization we have what we have done so far is we covered this and I think this is already sufficient to pass the course uh but um right now we will cover these things and as I mentioned previously reproducibility is kind of cover it already cuz all we do make sure um that results are reproducible and we'll just need to also probably do a video on best practices but for now we'll cover just these two before we start I want to quickly talk about the changes I made to read me so I just rearranged things slightly um so what I did so I created the section code where I described that the code is in this uh folder then listed the files then I'll add description for each file and then in this section uh code uh we have um like how we run uh how we run it uh inje script um yeah what else here I added a section on experiments where I described that all the experiments uh we have notebooks where we keep the experiments and this is how we start the notebook these are the notebooks we have and then I put the evaluation there um it's a slight change uh then as I said at the end the read me file will look different anyways um but maybe this way it's a bit easier for you to keep track of the changes so this is the version we have so far yeah so I want to add a few pictures later but um yeah this is the structure we have so far we have data which we keep here this is the code and these are our experiments okay so let's start with monitoring and containerization we cover them at the same time and I will start by going to this monitoring thing and yeah we have app and we have Docker compost and I want to copy the docker compost file here Y and what do we need from here elastic search we don't need Alama we don't need we need um pogress and we need our app so for our app we need to create a Docker file from um I'll use uh python 3.2 slim uh and then I'll add more stuff later but this will be our um Docker file right container name I don't actually know why we need container name so let's remove that um this is something we will adjust to uh for now I'll just comment this and Port uh let app port, 5,000 it depends on pogress right don't have things grafana we keep grafana of course two and I'll create do file two what do we actually have in the do end file I'll copy it we don't need these things ort and this was uh 5,000 right okay um [Music] so cool I will remove these things for now okay so this is what we have so far and now I want to add we want to add monitoring and for that we have this prep script and BB script so let me copy prep or DB prep here uh we don't need this this we don't need this we don't need this so this is elastic search stuff actually we don't need that much from here so you would need this if you had elastic search but from what I see the only thing we need here is initializing the database and yeah I guess the only reason that we need this is we have this uh main thing so then we can easily initialize the database so then I can actually put it here and and here we'll create db. Pi do PI with these things all right uh okay so I don't think we need to um change anything here conversation ID feedback time stamp yeah I think we can just use it as uh as is without changing anything okay right we also need to [Music] install install psyo pg2 binary I hope I brought it correctly this is for the PG connection po G connection so now when let me actually in a different I'll stop it I want to stop it it doesn't stop stopped so I want to actually um what's happening stop I want to do Docker compose up and we need to start putting these things in the r me too cuz so far we described how to start it without doer compose um it with docker Rush compos up uh I can mention that the e ...

# %%
link_transcripts
# Out:
# [{'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'hi everyone welcome to our course this',
#   'TimeStamp': 0.719,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=0s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'is our first module for first unit so in',
#   'TimeStamp': 3.04,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=3s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'this course the course is called llm',
#   'TimeStamp': 7.0,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=7s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'zoom camp in this course we will learn',
#   'TimeStamp': 9.08,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=9s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'about practical applications of llm and',
#   'TimeStamp': 12.04,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=12s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'in particular we will focus our',
#   'TimeStamp': 14.879,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=14s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'attention on rack retrieval a generation',
#   'TimeStamp': 16.76,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=16s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "i'll shortly talk about these variations",
#   'TimeStamp': 19.88,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=19s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'what they mean um and what we exactly',
#   'TimeStamp': 22.8,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=22s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'will do and i want to start first with',
#   'TimeStamp': 26.199,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=26s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'explaining the problem we are going to',
#   'TimeStamp': 30.039,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=30s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'use uh to solve throughout the',
#   'TimeStamp': 32.16,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=32s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'course um so this will be our running',
#   'TimeStamp': 34.84,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=34s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'problem and in our community in data do',
#   'TimeStamp': 38.079,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=38s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'club we have multiple',
#   'TimeStamp': 41.64,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=41s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'courses so this llm zoom camp is our',
#   'TimeStamp': 43.96,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=43s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'fifth',
#   'TimeStamp': 47.32,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=47s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'course and usually in our courses we',
#   'TimeStamp': 48.92,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=48s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'have frequently asked questions so there',
#   'TimeStamp': 51.879,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=51s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'are questions that uh there are no',
#   'TimeStamp': 54.039,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=54s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'answers in the videos or answers are not',
#   'TimeStamp': 57.199,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=57s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'uh',
#   'TimeStamp': 59.76,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=59s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'easy to find and we have these documents',
#   'TimeStamp': 61.399,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=61s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "i'll quickly open one of",
#   'TimeStamp': 64.879,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=64s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'them',
#   'TimeStamp': 67.4,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=67s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'and in these documents we have',
#   'TimeStamp': 70.04,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=70s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'frequently asked questions so the format',
#   'TimeStamp': 73.52,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=73s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "is there is a section then there's a",
#   'TimeStamp': 77.4,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=77s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'question then there is an answer and',
#   'TimeStamp': 81.6,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=81s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'this is like that question answer',
#   'TimeStamp': 84.28,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=84s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'question',
#   'TimeStamp': 86.84,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=86s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'answer and we have quite quite a few of',
#   'TimeStamp': 87.759,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=87s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'them so in this particular document for',
#   'TimeStamp': 90.439,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=90s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'the data engineering zoom camp we have',
#   'TimeStamp': 92.399,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=92s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': '321 page of such',
#   'TimeStamp': 95.92,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=95s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'answers and typically we ask the',
#   'TimeStamp': 100.399,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=100s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'students',
#   'TimeStamp': 103.2,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=103s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'to uh use this document so before they',
#   'TimeStamp': 104.439,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=104s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'uh go to slack to the channel to the',
#   'TimeStamp': 107.799,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=107s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'group to the course channel uh we ask',
#   'TimeStamp': 110.24,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=110s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'them to check this document first before',
#   'TimeStamp': 113.399,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=113s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'they ask a',
#   'TimeStamp': 115.6,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=115s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'question and of course um most of the',
#   'TimeStamp': 117.0,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=117s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'questions they have the students have',
#   'TimeStamp': 120.719,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=120s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'they will find here but the problem is',
#   'TimeStamp': 123.079,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=123s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "that it's not super easy to",
#   'TimeStamp': 125.84,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=125s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'find right so there are 321 questions',
#   'TimeStamp': 129.36,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=129s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'like how do you actually find the',
#   'TimeStamp': 133.12,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=133s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'information you need here so this is not',
#   'TimeStamp': 135.8,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=135s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "trial that's why we will use the data",
#   'TimeStamp': 139.04,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=139s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'from uh these faqs from the three faqs',
#   'TimeStamp': 142.72,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=142s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'from the three courses and we will beat',
#   'TimeStamp': 146.16,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=146s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'a b we will build a report a q&a system',
#   'TimeStamp': 148.56,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=148s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'that given a question from a potential',
#   'TimeStamp': 151.959,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=151s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'student will use the documents the fq',
#   'TimeStamp': 154.48,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=154s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'documents uh these particular documents',
#   'TimeStamp': 158.08,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=158s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'to answer questions from the students so',
#   'TimeStamp': 160.4,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=160s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'this is what we are going to build at',
#   'TimeStamp': 162.8,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=162s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'end it will be a simple form this is how',
#   'TimeStamp': 164.879,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=164s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'i see right now we have not buil it yet',
#   'TimeStamp': 167.48,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=167s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'it will be a simple form where you',
#   'TimeStamp': 169.56,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=169s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'put an answer a question and get back',
#   'TimeStamp': 172.0,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=172s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'answer so how we are going to do this we',
#   'TimeStamp': 176.519,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=176s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'are going to to',
#   'TimeStamp': 179.4,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=179s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'use llms and tracks so what they are and',
#   'TimeStamp': 180.8,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=180s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'this is exactly what we are going to',
#   'TimeStamp': 185.08,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=185s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'talk about in this module so now we will',
#   'TimeStamp': 187.04,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=187s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "talk about lms we'll talk about rack",
#   'TimeStamp': 190.879,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=190s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'what the rack is and what exactly we are',
#   'TimeStamp': 193.519,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=193s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'going to cover um well what exactly you',
#   'TimeStamp': 196.799,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=196s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'will learn in the course um and what you',
#   'TimeStamp': 200.12,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=200s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "will build so let's",
#   'TimeStamp': 204.36,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=204s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'start so',
#   'TimeStamp': 208.08,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=208s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'and we will start with what llms are so',
#   'TimeStamp': 210.76,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=210s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'llms or llm it it stands for um large',
#   'TimeStamp': 214.36,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=214s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'language',
#   'TimeStamp': 219.76,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=219s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'model lge language',
#   'TimeStamp': 220.799,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=220s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'model uh and we can start with just',
#   'TimeStamp': 224.519,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=224s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'language',
#   'TimeStamp': 228.08,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=228s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'model so language models are things that',
#   'TimeStamp': 230.439,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=230s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'predict the next token the next word',
#   'TimeStamp': 234.239,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=234s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'based on the words you have typed so far',
#   'TimeStamp': 237.2,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=237s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'or you have so far in your document so',
#   'TimeStamp': 240.92,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=240s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'imagine your phone right so you open',
#   'TimeStamp': 244.0,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=244s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'whatsapp and you want to text somebody',
#   'TimeStamp': 246.92,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=246s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "let's say you want to text your body",
#   'TimeStamp': 249.799,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=249s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'your friend so you start typing how',
#   'TimeStamp': 252.4,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=252s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'space i space and the phone your phone',
#   'TimeStamp': 255.439,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=255s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'will typically suggest you as the next',
#   'TimeStamp': 258.959,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=258s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'logical word because typically what you',
#   'TimeStamp': 262.68,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=262s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'type is how are you so it recognizes how',
#   'TimeStamp': 264.96,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=264s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'are so logically the next word be you',
#   'TimeStamp': 267.4,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=267s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'right or how are there maybe you want to',
#   'TimeStamp': 271.16,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=271s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'ask how are the things right so it',
#   'TimeStamp': 274.16,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=274s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'suggests you commonly common words that',
#   'TimeStamp': 276.6,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=276s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'go after how are and um also on your',
#   'TimeStamp': 279.639,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=279s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'phone this is personalized to you and',
#   'TimeStamp': 284.96,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=284s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'your phones use language models for that',
#   'TimeStamp': 288.56,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=288s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "so typically it's something simple like",
#   'TimeStamp': 291.16,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=291s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'na base uh that just predicts the sec',
#   'TimeStamp': 293.24,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=293s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'the next word based on what you typed of',
#   'TimeStamp': 296.759,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=296s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'far so these are just simple or we can',
#   'TimeStamp': 299.8,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=299s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'call them small language models so they',
#   'TimeStamp': 302.88,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=302s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "don't have a lot of parameters um",
#   'TimeStamp': 305.199,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=305s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "they're quite simple they're also quite",
#   'TimeStamp': 308.44,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=308s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "um how to say stupid let's say because",
#   'TimeStamp': 311.12,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=311s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'stupid compared to large language models',
#   'TimeStamp': 315.68,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=315s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'so lot usual simple language models do',
#   'TimeStamp': 318.24,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=318s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'their job fine but large large language',
#   'TimeStamp': 321.039,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=321s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "models u there's a reason they call",
#   'TimeStamp': 324.44,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=324s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'large because they are huge so they have',
#   'TimeStamp': 326.479,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=326s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'a lot of param they have billions and',
#   'TimeStamp': 328.88,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=328s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'billions and billions of parameters and',
#   'TimeStamp': 331.0,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=331s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'then they are trained on tons and tons',
#   'TimeStamp': 333.52,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=333s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'of',
#   'TimeStamp': 336.36,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=336s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'data and what they do is essentially the',
#   'TimeStamp': 337.72,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=337s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'same they predict the next word based on',
#   'TimeStamp': 340.84,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=340s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'the words',
#   'TimeStamp': 344.08,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=344s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'before but the way they do it it feels',
#   'TimeStamp': 345.56,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=345s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "like you're talking to a human at least",
#   'TimeStamp': 348.919,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=348s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'if you use something like ch',
#   'TimeStamp': 351.84,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=351s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "gpt yeah it feels like you're talking to",
#   'TimeStamp': 355.6,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=355s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'an intelligent being because it',
#   'TimeStamp': 358.199,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=358s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'understands what you ask and gives',
#   'TimeStamp': 360.24,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=360s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'answers uh but under the hood this is a',
#   'TimeStamp': 363.24,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=363s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'language model with tons and tons and',
#   'TimeStamp': 366.84,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=366s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'tons of perameters and train trained on',
#   'TimeStamp': 369.4,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=369s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'tons and tons and tons of data inside uh',
#   'TimeStamp': 371.759,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=371s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'let',
#   'TimeStamp': 375.52,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=375s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'me let me draw a oops let me draw an llm',
#   'TimeStamp': 377.08,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=377s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'here so it will be a box like',
#   'TimeStamp': 381.12,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=381s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'that so',
#   'TimeStamp': 385.4,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=385s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'inside they use uh neur networks like',
#   'TimeStamp': 387.319,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=387s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'transformers but we actually will not go',
#   'TimeStamp': 390.56,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=390s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'into that so in this course we will not',
#   'TimeStamp': 394.36,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=394s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'cover the theory behind llms we will not',
#   'TimeStamp': 397.28,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=397s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'try to look inside the llms and we are',
#   'TimeStamp': 400.36,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=400s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'going to treat them as black boxes so to',
#   'TimeStamp': 403.68,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=403s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'our purposes this is a super smart thing',
#   'TimeStamp': 406.599,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=406s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'that can figure out what you ask and',
#   'TimeStamp': 410.319,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=410s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'give meaningful answers so this is how',
#   'TimeStamp': 412.84,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=412s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'we are going to use it and what is',
#   'TimeStamp': 415.599,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=415s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "inside it's for us in this particular",
#   'TimeStamp': 418.199,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=418s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'course is secondary there are a lot of',
#   'TimeStamp': 421.12,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=421s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'there are a lot of courses already a lot',
#   'TimeStamp': 424.039,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=424s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'of books that talk about um the',
#   'TimeStamp': 426.36,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=426s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'internals of llms but here we will not',
#   'TimeStamp': 429.72,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=429s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'cover that and typically so lm receives',
#   'TimeStamp': 432.72,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=432s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'an',
#   'TimeStamp': 436.479,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=436s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'input so we will talk about the simple',
#   'TimeStamp': 438.28,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=438s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'case when the input is',
#   'TimeStamp': 441.039,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=441s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'text and we usually call this input',
#   'TimeStamp': 443.08,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=443s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'prompt so this is what goes in inside',
#   'TimeStamp': 447.0,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=447s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'the llm and the output is some',
#   'TimeStamp': 450.28,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=450s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'answer so how a prompt may look',
#   'TimeStamp': 456.84,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=456s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "like um for example this is what we're",
#   'TimeStamp': 460.039,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=460s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'going to use in the course is a question',
#   'TimeStamp': 462.759,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=462s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'like um so this is the course uh this is',
#   'TimeStamp': 465.319,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=465s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'the prompt it starts with',
#   'TimeStamp': 469.96,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=469s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'question',
#   'TimeStamp': 473.68,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=473s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'um how do i enroll in the course',
#   'TimeStamp': 475.599,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=475s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'context based on what we should answer',
#   'TimeStamp': 480.96,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=480s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'the question and there will be some',
#   'TimeStamp': 483.599,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=483s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'context and then answer and after that',
#   'TimeStamp': 485.4,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=485s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'we may just leave it at that so answer',
#   'TimeStamp': 489.24,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=489s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "colum and that's it and remember i",
#   'TimeStamp': 493.12,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=493s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'talked about language models so the what',
#   'TimeStamp': 495.84,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=495s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'language models do is they complete the',
#   'TimeStamp': 497.879,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=497s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'input and they find the next logical',
#   'TimeStamp': 502.8,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=502s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'term or the next logical uh word for',
#   'TimeStamp': 505.52,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=505s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'that right so it is that',
#   'TimeStamp': 509.199,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=509s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'answer column so expect it expects based',
#   'TimeStamp': 512.08,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=512s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'on the context it expects an answer to',
#   'TimeStamp': 516.919,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=516s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'the question or we expect it so it will',
#   'TimeStamp': 519.2,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=519s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'try to to do that so this is a prompt uh',
#   'TimeStamp': 522.959,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=522s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'an example of a prompt modern llms like',
#   'TimeStamp': 526.68,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=526s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "chbd you don't actually need to do that",
#   'TimeStamp': 530.519,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=530s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "like you don't need to write answer at",
#   'TimeStamp': 533.839,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=533s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'the end uh but this is just an example',
#   'TimeStamp': 535.24,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=535s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'right and the answer could be',
#   'TimeStamp': 537.68,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=537s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'actual answer right everything that goes',
#   'TimeStamp': 540.44,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=540s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'after after',
#   'TimeStamp': 543.04,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=543s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'this so these are',
#   'TimeStamp': 546.16,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=546s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'llms and the next thing we will talk',
#   'TimeStamp': 549.959,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=549s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'about uh is rock so rock stands for the',
#   'TimeStamp': 553.0,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=553s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'retrieval',
#   'TimeStamp': 560.24,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=560s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'generation and i think i made it toway',
#   'TimeStamp': 562.6,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=562s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'here',
#   'TimeStamp': 565.04,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=565s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'augmented so what it means is generation',
#   'TimeStamp': 566.2,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=566s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'there are two two things that are',
#   'TimeStamp': 570.24,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=570s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'interesting here generation and',
#   'TimeStamp': 571.399,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=571s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'retrieval so we use retrieval to augment',
#   'TimeStamp': 573.399,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=573s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'generation so',
#   'TimeStamp': 577.519,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=577s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'retrieval is nothing else but search and',
#   'TimeStamp': 580.959,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=580s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'generation is llm so llms generate text',
#   'TimeStamp': 585.959,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=585s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'and they use search to augment the',
#   'TimeStamp': 589.72,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=589s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'generation of this',
#   'TimeStamp': 591.839,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=591s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'text what exactly does it mean so i have',
#   'TimeStamp': 593.56,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=593s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'a few examples why we need track why do',
#   'TimeStamp': 597.079,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=597s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'we need to augment our generation',
#   'TimeStamp': 599.839,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=599s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "search so let's see yeah so these are",
#   'TimeStamp': 608.04,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=608s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'the example',
#   'TimeStamp': 611.6,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=611s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'so i have asked a',
#   'TimeStamp': 613.519,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=613s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'question uh to chpt and the question is',
#   'TimeStamp': 616.839,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=616s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'how do i cook cell one and then this is',
#   'TimeStamp': 620.399,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=620s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'a straightforward question ch gpt gives',
#   'TimeStamp': 622.839,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=622s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'a very comprehensive answer right so um',
#   'TimeStamp': 625.64,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=625s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'like there is a lot of uh ways to cook',
#   'TimeStamp': 629.839,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=629s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'salman like five quite a lot right so',
#   'TimeStamp': 632.12,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=632s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': "this is a perfect example when we don't",
#   'TimeStamp': 637.639,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=637s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'need search like we have a question llm',
#   'TimeStamp': 639.76,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=639s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'knows the answer and llm gives us the',
#   'TimeStamp': 642.44,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=642s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'answer but what if we want to ask it',
#   'TimeStamp': 644.72,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=644s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'about the course so ask is it too late',
#   'TimeStamp': 647.88,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=647s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'for me to join the course right but the',
#   'TimeStamp': 651.0,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=651s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'llm has no idea what we talk about like',
#   'TimeStamp': 653.72,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=653s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'which course is it too late what what',
#   'TimeStamp': 656.6,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=656s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'does it mean exactly',
#   'TimeStamp': 658.48,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=658s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'right and then it says i can help you',
#   'TimeStamp': 659.76,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=659s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'but i need to know more details right so',
#   'TimeStamp': 662.88,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=662s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'can you tell me more about that and the',
#   'TimeStamp': 665.68,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=665s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'reason we want to use search is actually',
#   'TimeStamp': 668.48,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=668s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'to answer that to give it more',
#   'TimeStamp': 671.48,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=671s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'information to give it more context such',
#   'TimeStamp': 673.519,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=673s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'that the llm is able to give the answer',
#   'TimeStamp': 676.6,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=676s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'right and this is another example like',
#   'TimeStamp': 681.36,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=681s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'how do i enroll in the course again it',
#   'TimeStamp': 684.279,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=684s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'has no clue what we ask about but like',
#   'TimeStamp': 686.72,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=686s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'it just give some answer that is',
#   'TimeStamp': 688.6,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=688s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'nonsense right um another good example',
#   'TimeStamp': 691.68,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=691s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'where we use uh we use uh retrieval also',
#   'TimeStamp': 696.44,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=696s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'in chbt is we can ask it uh look up in',
#   'TimeStamp': 700.079,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=700s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': ' how to enroll in',
#   'TimeStamp': 705.6,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=705s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'data engineering zoom camp',
#   'TimeStamp': 709.399,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=709s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'and so here we give it explicitly an',
#   'TimeStamp': 714.16,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=714s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'instruction to',
#   'TimeStamp': 716.88,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=716s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'uh perform a search and then based on',
#   'TimeStamp': 719.68,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=719s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'the results of the search give us the',
#   'TimeStamp': 722.279,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=722s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'answer so this is an example of rack so',
#   'TimeStamp': 725.12,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=725s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'we augment the generation with the',
#   'TimeStamp': 728.36,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=728s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'context we get from search and this is',
#   'TimeStamp': 731.04,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=731s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'similar more similar to what we are',
#   'TimeStamp': 735.72,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=735s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'going to',
#   'TimeStamp': 737.56,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=737s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
#   'Text': 'build',
#   'TimeStamp': 738.519,
#   'link': 'https://www.youtube.com/watch?v=Q75JgLEXMsM&t=738s'},
#  {'Title': 'llm zoomcamp 1.1 - introduction to llm and rag',
# ...
#   'TimeStamp': 594.76,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=594s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'this search engine to perform',
#   'TimeStamp': 597.24,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=597s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'uh to execute this query and see what',
#   'TimeStamp': 600.32,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=600s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'documents are relevant for this',
#   'TimeStamp': 603.44,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=603s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': "query so now let's say we perform the",
#   'TimeStamp': 605.839,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=605s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'search and here we have a bunch of',
#   'TimeStamp': 610.279,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=610s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'things a bunch of arguments so the',
#   'TimeStamp': 613.56,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=613s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'actual',
#   'TimeStamp': 616.04,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=616s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'query this is um the query that i',
#   'TimeStamp': 617.279,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=617s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'provided the course has already started',
#   'TimeStamp': 620.68,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=620s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'can i still',
#   'TimeStamp': 622.519,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=622s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'enroll then we have um boost',
#   'TimeStamp': 623.6,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=623s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'so boost is um when we think that one of',
#   'TimeStamp': 629.44,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=629s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'the text fields is more important than',
#   'TimeStamp': 634.2,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=634s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'the other we can boost this um this',
#   'TimeStamp': 637.639,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=637s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'field we can say that',
#   'TimeStamp': 640.8,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=640s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'if the question field contains the word',
#   'TimeStamp': 643.16,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=643s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': "course started en roll then it's more",
#   'TimeStamp': 647.639,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=647s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'important than if the answer contains',
#   'TimeStamp': 651.24,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=651s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'these words right so then we want to',
#   'TimeStamp': 654.519,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=654s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'give more importance to the the question',
#   'TimeStamp': 657.12,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=657s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'term and this is we do with',
#   'TimeStamp': 660.56,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=660s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'boosting and actually these are all',
#   'TimeStamp': 662.8,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=662s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'terms from elastic search so we just',
#   'TimeStamp': 666.16,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=666s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'reimplemented it uh with secondy la and',
#   'TimeStamp': 668.639,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=668s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'pandas in the workshop but all these',
#   'TimeStamp': 671.92,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=671s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'terms come from lastic search or',
#   'TimeStamp': 674.44,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=674s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'actually from lucine and lucine is the',
#   'TimeStamp': 676.36,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=676s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'search engine that elastic search uses',
#   'TimeStamp': 678.639,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=678s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'under the hood so we give a boost of',
#   'TimeStamp': 680.6,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=680s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': "five to let's give it three a boost of",
#   'TimeStamp': 684.88,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=684s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'three to the teex',
#   'TimeStamp': 688.44,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=688s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'to the question field meaning',
#   'TimeStamp': 689.76,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=689s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'that the question field is three times',
#   'TimeStamp': 692.6,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=692s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'more important than uh the text field',
#   'TimeStamp': 695.399,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=695s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': "and for example let's say we want to",
#   'TimeStamp': 699.2,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=699s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'have',
#   'TimeStamp': 701.24,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=701s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'section uh less important to give',
#   'TimeStamp': 702.16,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=702s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'section less importance then we can say',
#   'TimeStamp': 704.36,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=704s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': "that um it's by default it's one like",
#   'TimeStamp': 706.6,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=706s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'all fields have the importance of one',
#   'TimeStamp': 711.2,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=711s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'boost of one and we can give less',
#   'TimeStamp': 714.8,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=714s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'importance by giving zero .5 or more',
#   'TimeStamp': 717.68,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=717s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'importance by giving like more than one',
#   'TimeStamp': 720.079,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=720s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'like',
#   'TimeStamp': 722.48,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=722s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'three then so boost dictionary is this',
#   'TimeStamp': 724.279,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=724s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'boost and what else do we have there is',
#   'TimeStamp': 727.92,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=727s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'a third parameter which is number',
#   'TimeStamp': 730.519,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=730s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'results so this is the amount of results',
#   'TimeStamp': 733.279,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=733s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': "it returns let's say",
#   'TimeStamp': 736.399,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=736s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'five this is',
#   'TimeStamp': 738.56,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=738s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'results so now we perform a',
#   'TimeStamp': 740.6,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=740s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'search and this is what the results',
#   'TimeStamp': 744.04,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=744s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'are and and the top relevant documents',
#   'TimeStamp': 748.0,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=748s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': "are yes you can you won't be able to",
#   'TimeStamp': 751.44,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=751s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'submit some of the',
#   'TimeStamp': 753.24,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=753s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'homeworks um so actually like this is',
#   'TimeStamp': 755.04,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=755s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'exactly the same question that we uh try',
#   'TimeStamp': 757.76,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=757s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'to find the answer to the course has',
#   'TimeStamp': 760.399,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=760s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': "already started can i still join um it's",
#   'TimeStamp': 762.88,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=762s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'a little bit different because like we',
#   'TimeStamp': 765.6,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=765s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'used enroll not join but still we were',
#   'TimeStamp': 767.0,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=767s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'able to retrieve this document um by the',
#   'TimeStamp': 770.839,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=770s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'way so we also noticed that um here we',
#   'TimeStamp': 774.16,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=774s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': "actually retrieve so let's say if we",
#   'TimeStamp': 778.12,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=778s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'want to build a q&a system for the data',
#   'TimeStamp': 780.56,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=780s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'engineering course so we want to be able',
#   'TimeStamp': 783.199,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=783s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'to restrict our answers only to the data',
#   'TimeStamp': 785.519,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=785s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'engineering uh records so here we',
#   'TimeStamp': 789.12,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=789s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'retrieved a record from another faq not',
#   'TimeStamp': 792.44,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=792s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'from the data engineer fq so which means',
#   'TimeStamp': 795.639,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=795s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'we also need to add a',
#   'TimeStamp': 798.519,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=798s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'filter which is another parameter here',
#   'TimeStamp': 801.04,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=801s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'so we can say that look we are only',
#   'TimeStamp': 804.199,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=804s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'interested in documents for the',
#   'TimeStamp': 806.72,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=806s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'data engineering',
#   'TimeStamp': 810.079,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=810s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'engineering zoom camp so only give me',
#   'TimeStamp': 813.959,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=813s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'the documents that are about um the',
#   'TimeStamp': 817.6,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=817s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'course and now the results should be',
#   'TimeStamp': 820.92,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=820s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'different so now we only have um the',
#   'TimeStamp': 823.519,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=823s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'data engineering zoom camp answers and',
#   'TimeStamp': 827.519,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=827s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'again the first answer is quite relevant',
#   'TimeStamp': 831.16,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=831s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'can i still join the course after the',
#   'TimeStamp': 834.44,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=834s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'start date and this is the answer right',
#   'TimeStamp': 835.839,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=835s'},
#  {'Title': 'llm zoomcamp 1.3 - retrieval and search',
#   'Text': 'so',
#   'TimeStamp': 838.72,
#   'link': 'https://www.youtube.com/watch?v=olvem333Bqo&t=838s'},
#  ...]

# %%
timestamp_transcripts
# Out:
# {'llm zoomcamp 1.1 - introduction to llm and rag': [{'Text': 'hi everyone welcome to our course this',
#    'TimeStamp': 0.719},
#   {'Text': 'is our first module for first unit so in', 'TimeStamp': 3.04},
#   {'Text': 'this course the course is called llm', 'TimeStamp': 7.0},
#   {'Text': 'zoom camp in this course we will learn', 'TimeStamp': 9.08},
#   {'Text': 'about practical applications of llm and', 'TimeStamp': 12.04},
#   {'Text': 'in particular we will focus our', 'TimeStamp': 14.879},
#   {'Text': 'attention on rack retrieval a generation', 'TimeStamp': 16.76},
#   {'Text': "i'll shortly talk about these variations", 'TimeStamp': 19.88},
#   {'Text': 'what they mean um and what we exactly', 'TimeStamp': 22.8},
#   {'Text': 'will do and i want to start first with', 'TimeStamp': 26.199},
#   {'Text': 'explaining the problem we are going to', 'TimeStamp': 30.039},
#   {'Text': 'use uh to solve throughout the', 'TimeStamp': 32.16},
#   {'Text': 'course um so this will be our running', 'TimeStamp': 34.84},
#   {'Text': 'problem and in our community in data do', 'TimeStamp': 38.079},
#   {'Text': 'club we have multiple', 'TimeStamp': 41.64},
#   {'Text': 'courses so this llm zoom camp is our', 'TimeStamp': 43.96},
#   {'Text': 'fifth', 'TimeStamp': 47.32},
#   {'Text': 'course and usually in our courses we', 'TimeStamp': 48.92},
#   {'Text': 'have frequently asked questions so there', 'TimeStamp': 51.879},
#   {'Text': 'are questions that uh there are no', 'TimeStamp': 54.039},
#   {'Text': 'answers in the videos or answers are not', 'TimeStamp': 57.199},
#   {'Text': 'uh', 'TimeStamp': 59.76},
#   {'Text': 'easy to find and we have these documents', 'TimeStamp': 61.399},
#   {'Text': "i'll quickly open one of", 'TimeStamp': 64.879},
#   {'Text': 'them', 'TimeStamp': 67.4},
#   {'Text': 'and in these documents we have', 'TimeStamp': 70.04},
#   {'Text': 'frequently asked questions so the format', 'TimeStamp': 73.52},
#   {'Text': "is there is a section then there's a", 'TimeStamp': 77.4},
#   {'Text': 'question then there is an answer and', 'TimeStamp': 81.6},
#   {'Text': 'this is like that question answer', 'TimeStamp': 84.28},
#   {'Text': 'question', 'TimeStamp': 86.84},
#   {'Text': 'answer and we have quite quite a few of', 'TimeStamp': 87.759},
#   {'Text': 'them so in this particular document for', 'TimeStamp': 90.439},
#   {'Text': 'the data engineering zoom camp we have', 'TimeStamp': 92.399},
#   {'Text': '321 page of such', 'TimeStamp': 95.92},
#   {'Text': 'answers and typically we ask the', 'TimeStamp': 100.399},
#   {'Text': 'students', 'TimeStamp': 103.2},
#   {'Text': 'to uh use this document so before they', 'TimeStamp': 104.439},
#   {'Text': 'uh go to slack to the channel to the', 'TimeStamp': 107.799},
#   {'Text': 'group to the course channel uh we ask', 'TimeStamp': 110.24},
#   {'Text': 'them to check this document first before', 'TimeStamp': 113.399},
#   {'Text': 'they ask a', 'TimeStamp': 115.6},
#   {'Text': 'question and of course um most of the', 'TimeStamp': 117.0},
#   {'Text': 'questions they have the students have', 'TimeStamp': 120.719},
#   {'Text': 'they will find here but the problem is', 'TimeStamp': 123.079},
#   {'Text': "that it's not super easy to", 'TimeStamp': 125.84},
#   {'Text': 'find right so there are 321 questions', 'TimeStamp': 129.36},
#   {'Text': 'like how do you actually find the', 'TimeStamp': 133.12},
#   {'Text': 'information you need here so this is not', 'TimeStamp': 135.8},
#   {'Text': "trial that's why we will use the data", 'TimeStamp': 139.04},
#   {'Text': 'from uh these faqs from the three faqs', 'TimeStamp': 142.72},
#   {'Text': 'from the three courses and we will beat', 'TimeStamp': 146.16},
#   {'Text': 'a b we will build a report a q&a system', 'TimeStamp': 148.56},
#   {'Text': 'that given a question from a potential', 'TimeStamp': 151.959},
#   {'Text': 'student will use the documents the fq', 'TimeStamp': 154.48},
#   {'Text': 'documents uh these particular documents', 'TimeStamp': 158.08},
#   {'Text': 'to answer questions from the students so', 'TimeStamp': 160.4},
#   {'Text': 'this is what we are going to build at', 'TimeStamp': 162.8},
#   {'Text': 'end it will be a simple form this is how', 'TimeStamp': 164.879},
#   {'Text': 'i see right now we have not buil it yet', 'TimeStamp': 167.48},
#   {'Text': 'it will be a simple form where you', 'TimeStamp': 169.56},
#   {'Text': 'put an answer a question and get back', 'TimeStamp': 172.0},
#   {'Text': 'answer so how we are going to do this we', 'TimeStamp': 176.519},
#   {'Text': 'are going to to', 'TimeStamp': 179.4},
#   {'Text': 'use llms and tracks so what they are and', 'TimeStamp': 180.8},
#   {'Text': 'this is exactly what we are going to', 'TimeStamp': 185.08},
#   {'Text': 'talk about in this module so now we will', 'TimeStamp': 187.04},
#   {'Text': "talk about lms we'll talk about rack", 'TimeStamp': 190.879},
#   {'Text': 'what the rack is and what exactly we are', 'TimeStamp': 193.519},
#   {'Text': 'going to cover um well what exactly you', 'TimeStamp': 196.799},
#   {'Text': 'will learn in the course um and what you', 'TimeStamp': 200.12},
#   {'Text': "will build so let's", 'TimeStamp': 204.36},
#   {'Text': 'start so', 'TimeStamp': 208.08},
#   {'Text': 'and we will start with what llms are so', 'TimeStamp': 210.76},
#   {'Text': 'llms or llm it it stands for um large', 'TimeStamp': 214.36},
#   {'Text': 'language', 'TimeStamp': 219.76},
#   {'Text': 'model lge language', 'TimeStamp': 220.799},
#   {'Text': 'model uh and we can start with just', 'TimeStamp': 224.519},
#   {'Text': 'language', 'TimeStamp': 228.08},
#   {'Text': 'model so language models are things that', 'TimeStamp': 230.439},
#   {'Text': 'predict the next token the next word', 'TimeStamp': 234.239},
#   {'Text': 'based on the words you have typed so far', 'TimeStamp': 237.2},
#   {'Text': 'or you have so far in your document so', 'TimeStamp': 240.92},
#   {'Text': 'imagine your phone right so you open', 'TimeStamp': 244.0},
#   {'Text': 'whatsapp and you want to text somebody', 'TimeStamp': 246.92},
#   {'Text': "let's say you want to text your body", 'TimeStamp': 249.799},
#   {'Text': 'your friend so you start typing how', 'TimeStamp': 252.4},
#   {'Text': 'space i space and the phone your phone', 'TimeStamp': 255.439},
#   {'Text': 'will typically suggest you as the next', 'TimeStamp': 258.959},
#   {'Text': 'logical word because typically what you', 'TimeStamp': 262.68},
#   {'Text': 'type is how are you so it recognizes how', 'TimeStamp': 264.96},
#   {'Text': 'are so logically the next word be you', 'TimeStamp': 267.4},
#   {'Text': 'right or how are there maybe you want to', 'TimeStamp': 271.16},
#   {'Text': 'ask how are the things right so it', 'TimeStamp': 274.16},
#   {'Text': 'suggests you commonly common words that', 'TimeStamp': 276.6},
#   {'Text': 'go after how are and um also on your', 'TimeStamp': 279.639},
#   {'Text': 'phone this is personalized to you and', 'TimeStamp': 284.96},
#   {'Text': 'your phones use language models for that', 'TimeStamp': 288.56},
#   {'Text': "so typically it's something simple like", 'TimeStamp': 291.16},
#   {'Text': 'na base uh that just predicts the sec', 'TimeStamp': 293.24},
#   {'Text': 'the next word based on what you typed of', 'TimeStamp': 296.759},
#   {'Text': 'far so these are just simple or we can', 'TimeStamp': 299.8},
#   {'Text': 'call them small language models so they', 'TimeStamp': 302.88},
#   {'Text': "don't have a lot of parameters um", 'TimeStamp': 305.199},
#   {'Text': "they're quite simple they're also quite", 'TimeStamp': 308.44},
#   {'Text': "um how to say stupid let's say because", 'TimeStamp': 311.12},
#   {'Text': 'stupid compared to large language models', 'TimeStamp': 315.68},
#   {'Text': 'so lot usual simple language models do', 'TimeStamp': 318.24},
#   {'Text': 'their job fine but large large language', 'TimeStamp': 321.039},
#   {'Text': "models u there's a reason they call", 'TimeStamp': 324.44},
#   {'Text': 'large because they are huge so they have', 'TimeStamp': 326.479},
#   {'Text': 'a lot of param they have billions and', 'TimeStamp': 328.88},
#   {'Text': 'billions and billions of parameters and', 'TimeStamp': 331.0},
#   {'Text': 'then they are trained on tons and tons', 'TimeStamp': 333.52},
#   {'Text': 'of', 'TimeStamp': 336.36},
#   {'Text': 'data and what they do is essentially the', 'TimeStamp': 337.72},
#   {'Text': 'same they predict the next word based on', 'TimeStamp': 340.84},
#   {'Text': 'the words', 'TimeStamp': 344.08},
#   {'Text': 'before but the way they do it it feels', 'TimeStamp': 345.56},
#   {'Text': "like you're talking to a human at least", 'TimeStamp': 348.919},
#   {'Text': 'if you use something like ch', 'TimeStamp': 351.84},
#   {'Text': "gpt yeah it feels like you're talking to", 'TimeStamp': 355.6},
#   {'Text': 'an intelligent being because it', 'TimeStamp': 358.199},
#   {'Text': 'understands what you ask and gives', 'TimeStamp': 360.24},
#   {'Text': 'answers uh but under the hood this is a', 'TimeStamp': 363.24},
#   {'Text': 'language model with tons and tons and', 'TimeStamp': 366.84},
#   {'Text': 'tons of perameters and train trained on', 'TimeStamp': 369.4},
#   {'Text': 'tons and tons and tons of data inside uh', 'TimeStamp': 371.759},
#   {'Text': 'let', 'TimeStamp': 375.52},
#   {'Text': 'me let me draw a oops let me draw an llm', 'TimeStamp': 377.08},
#   {'Text': 'here so it will be a box like', 'TimeStamp': 381.12},
#   {'Text': 'that so', 'TimeStamp': 385.4},
#   {'Text': 'inside they use uh neur networks like', 'TimeStamp': 387.319},
#   {'Text': 'transformers but we actually will not go', 'TimeStamp': 390.56},
#   {'Text': 'into that so in this course we will not', 'TimeStamp': 394.36},
#   {'Text': 'cover the theory behind llms we will not', 'TimeStamp': 397.28},
#   {'Text': 'try to look inside the llms and we are', 'TimeStamp': 400.36},
#   {'Text': 'going to treat them as black boxes so to', 'TimeStamp': 403.68},
#   {'Text': 'our purposes this is a super smart thing', 'TimeStamp': 406.599},
#   {'Text': 'that can figure out what you ask and', 'TimeStamp': 410.319},
#   {'Text': 'give meaningful answers so this is how', 'TimeStamp': 412.84},
#   {'Text': 'we are going to use it and what is', 'TimeStamp': 415.599},
#   {'Text': "inside it's for us in this particular", 'TimeStamp': 418.199},
#   {'Text': 'course is secondary there are a lot of', 'TimeStamp': 421.12},
#   {'Text': 'there are a lot of courses already a lot', 'TimeStamp': 424.039},
#   {'Text': 'of books that talk about um the', 'TimeStamp': 426.36},
#   {'Text': 'internals of llms but here we will not', 'TimeStamp': 429.72},
#   {'Text': 'cover that and typically so lm receives', 'TimeStamp': 432.72},
#   {'Text': 'an', 'TimeStamp': 436.479},
#   {'Text': 'input so we will talk about the simple', 'TimeStamp': 438.28},
#   {'Text': 'case when the input is', 'TimeStamp': 441.039},
#   {'Text': 'text and we usually call this input', 'TimeStamp': 443.08},
#   {'Text': 'prompt so this is what goes in inside', 'TimeStamp': 447.0},
#   {'Text': 'the llm and the output is some', 'TimeStamp': 450.28},
#   {'Text': 'answer so how a prompt may look', 'TimeStamp': 456.84},
#   {'Text': "like um for example this is what we're", 'TimeStamp': 460.039},
#   {'Text': 'going to use in the course is a question', 'TimeStamp': 462.759},
#   {'Text': 'like um so this is the course uh this is', 'TimeStamp': 465.319},
#   {'Text': 'the prompt it starts with', 'TimeStamp': 469.96},
#   {'Text': 'question', 'TimeStamp': 473.68},
#   {'Text': 'um how do i enroll in the course', 'TimeStamp': 475.599},
#   {'Text': 'context based on what we should answer', 'TimeStamp': 480.96},
#   {'Text': 'the question and there will be some', 'TimeStamp': 483.599},
#   {'Text': 'context and then answer and after that', 'TimeStamp': 485.4},
#   {'Text': 'we may just leave it at that so answer', 'TimeStamp': 489.24},
#   {'Text': "colum and that's it and remember i", 'TimeStamp': 493.12},
#   {'Text': 'talked about language models so the what', 'TimeStamp': 495.84},
#   {'Text': 'language models do is they complete the', 'TimeStamp': 497.879},
#   {'Text': 'input and they find the next logical', 'TimeStamp': 502.8},
#   {'Text': 'term or the next logical uh word for', 'TimeStamp': 505.52},
#   {'Text': 'that right so it is that', 'TimeStamp': 509.199},
#   {'Text': 'answer column so expect it expects based', 'TimeStamp': 512.08},
#   {'Text': 'on the context it expects an answer to', 'TimeStamp': 516.919},
#   {'Text': 'the question or we expect it so it will', 'TimeStamp': 519.2},
#   {'Text': 'try to to do that so this is a prompt uh', 'TimeStamp': 522.959},
#   {'Text': 'an example of a prompt modern llms like', 'TimeStamp': 526.68},
#   {'Text': "chbd you don't actually need to do that", 'TimeStamp': 530.519},
#   {'Text': "like you don't need to write answer at", 'TimeStamp': 533.839},
#   {'Text': 'the end uh but this is just an example', 'TimeStamp': 535.24},
#   {'Text': 'right and the answer could be', 'TimeStamp': 537.68},
#   {'Text': 'actual answer right everything that goes', 'TimeStamp': 540.44},
#   {'Text': 'after after', 'TimeStamp': 543.04},
#   {'Text': 'this so these are', 'TimeStamp': 546.16},
#   {'Text': 'llms and the next thing we will talk', 'TimeStamp': 549.959},
#   {'Text': 'about uh is rock so rock stands for the', 'TimeStamp': 553.0},
#   {'Text': 'retrieval', 'TimeStamp': 560.24},
#   {'Text': 'generation and i think i made it toway', 'TimeStamp': 562.6},
#   {'Text': 'here', 'TimeStamp': 565.04},
#   {'Text': 'augmented so what it means is generation', 'TimeStamp': 566.2},
#   {'Text': 'there are two two things that are', 'TimeStamp': 570.24},
#   {'Text': 'interesting here generation and', 'TimeStamp': 571.399},
#   {'Text': 'retrieval so we use retrieval to augment', 'TimeStamp': 573.399},
#   {'Text': 'generation so', 'TimeStamp': 577.519},
#   {'Text': 'retrieval is nothing else but search and', 'TimeStamp': 580.959},
#   {'Text': 'generation is llm so llms generate text', 'TimeStamp': 585.959},
#   {'Text': 'and they use search to augment the', 'TimeStamp': 589.72},
#   {'Text': 'generation of this', 'TimeStamp': 591.839},
#   {'Text': 'text what exactly does it mean so i have', 'TimeStamp': 593.56},
#   {'Text': 'a few examples why we need track why do', 'TimeStamp': 597.079},
#   {'Text': 'we need to augment our generation', 'TimeStamp': 599.839},
#   {'Text': "search so let's see yeah so these are", 'TimeStamp': 608.04},
#   {'Text': 'the example', 'TimeStamp': 611.6},
#   {'Text': 'so i have asked a', 'TimeStamp': 613.519},
#   {'Text': 'question uh to chpt and the question is', 'TimeStamp': 616.839},
#   {'Text': 'how do i cook cell one and then this is', 'TimeStamp': 620.399},
#   {'Text': 'a straightforward question ch gpt gives', 'TimeStamp': 622.839},
#   {'Text': 'a very comprehensive answer right so um', 'TimeStamp': 625.64},
#   {'Text': 'like there is a lot of uh ways to cook', 'TimeStamp': 629.839},
#   {'Text': 'salman like five quite a lot right so', 'TimeStamp': 632.12},
#   {'Text': "this is a perfect example when we don't", 'TimeStamp': 637.639},
#   {'Text': 'need search like we have a question llm', 'TimeStamp': 639.76},
#   {'Text': 'knows the answer and llm gives us the', 'TimeStamp': 642.44},
#   {'Text': 'answer but what if we want to ask it', 'TimeStamp': 644.72},
#   {'Text': 'about the course so ask is it too late', 'TimeStamp': 647.88},
#   {'Text': 'for me to join the course right but the', 'TimeStamp': 651.0},
#   {'Text': 'llm has no idea what we talk about like', 'TimeStamp': 653.72},
#   {'Text': 'which course is it too late what what', 'TimeStamp': 656.6},
#   {'Text': 'does it mean exactly', 'TimeStamp': 658.48},
#   {'Text': 'right and then it says i can help you', 'TimeStamp': 659.76},
#   {'Text': 'but i need to know more details right so', 'TimeStamp': 662.88},
#   {'Text': 'can you tell me more about that and the', 'TimeStamp': 665.68},
#   {'Text': 'reason we want to use search is actually', 'TimeStamp': 668.48},
#   {'Text': 'to answer that to give it more', 'TimeStamp': 671.48},
#   {'Text': 'information to give it more context such', 'TimeStamp': 673.519},
#   {'Text': 'that the llm is able to give the answer', 'TimeStamp': 676.6},
#   {'Text': 'right and this is another example like', 'TimeStamp': 681.36},
#   {'Text': 'how do i enroll in the course again it', 'TimeStamp': 684.279},
#   {'Text': 'has no clue what we ask about but like', 'TimeStamp': 686.72},
#   {'Text': 'it just give some answer that is', 'TimeStamp': 688.6},
#   {'Text': 'nonsense right um another good example', 'TimeStamp': 691.68},
#   {'Text': 'where we use uh we use uh retrieval also', 'TimeStamp': 696.44},
#   {'Text': 'in chbt is we can ask it uh look up in', 'TimeStamp': 700.079},
#   {'Text': ' how to enroll in', 'TimeStamp': 705.6},
#   {'Text': 'data engineering zoom camp', 'TimeStamp': 709.399},
#   {'Text': 'and so here we give it explicitly an', 'TimeStamp': 714.16},
#   {'Text': 'instruction to', 'TimeStamp': 716.88},
#   {'Text': 'uh perform a search and then based on', 'TimeStamp': 719.68},
#   {'Text': 'the results of the search give us the', 'TimeStamp': 722.279},
#   {'Text': 'answer so this is an example of rack so', 'TimeStamp': 725.12},
#   {'Text': 'we augment the generation with the', 'TimeStamp': 728.36},
#   {'Text': 'context we get from search and this is', 'TimeStamp': 731.04},
#   {'Text': 'similar more similar to what we are', 'TimeStamp': 735.72},
#   {'Text': 'going to', 'TimeStamp': 737.56},
#   {'Text': 'build', 'TimeStamp': 738.519},
#   {'Text': 'um this instruction is quite good okay', 'TimeStamp': 740.199},
#   {'Text': 'so let me go back here so', 'TimeStamp': 744.48},
#   {'Text': 'search is the first component of rock so', 'TimeStamp': 748.16},
#   {'Text': 'we have like some sort of knowledge base', 'TimeStamp': 752.0},
#   {'Text': 'and then the other', 'TimeStamp': 755.24},
#   {'Text': 'component is the actual', 'TimeStamp': 756.56},
#   {'Text': 'llm and then um just remove', 'TimeStamp': 761.76},
#   {'Text': 'that um so we have two components', 'TimeStamp': 765.56},
#   {'Text': 'knowledge base', 'TimeStamp': 768.44},
#   {'Text': "andm and let's say we have a", 'TimeStamp': 769.639},
#   {'Text': 'user the user the student of the course', 'TimeStamp': 772.959},
#   {'Text': "or i don't know just the user if if we", 'TimeStamp': 776.36},
#   {'Text': 'talk about our example it could be a', 'TimeStamp': 779.399},
#   {'Text': 'student if we talk about some other', 'TimeStamp': 781.32},
#   {'Text': 'example could be just user and the user', 'TimeStamp': 782.92},
#   {'Text': 'has a question like how do i enroll in', 'TimeStamp': 785.68},
#   {'Text': 'the course so this question let me call', 'TimeStamp': 787.839},
#   {'Text': 'it', 'TimeStamp': 791.16},
#   {'Text': 'q so in rck what we do first is', 'TimeStamp': 792.079},
#   {'Text': 'we send this query or the question to', 'TimeStamp': 797.24},
#   {'Text': 'the knowledge', 'TimeStamp': 800.16},
#   {'Text': 'base and the knowledge base has some', 'TimeStamp': 801.959},
#   {'Text': 'article so this is our faq is a', 'TimeStamp': 805.639},
#   {'Text': 'knowledge base space right so it has um', 'TimeStamp': 808.68},
#   {'Text': 'some articles some answers some', 'TimeStamp': 811.68},
#   {'Text': 'questions and answers to these', 'TimeStamp': 813.48},
#   {'Text': 'questions so it could be like how do i', 'TimeStamp': 815.519},
#   {'Text': 'enroll in the course there are some uh', 'TimeStamp': 817.639},
#   {'Text': 'entries they talk about that so we', 'TimeStamp': 820.639},
#   {'Text': 'retrieve these', 'TimeStamp': 822.639},
#   {'Text': "entries and then later so let's say", 'TimeStamp': 823.839},
#   {'Text': "these are the documents uh i'll call", 'TimeStamp': 828.44},
#   {'Text': 'them', 'TimeStamp': 831.399},
#   {'Text': "t1 uh d2 etc d5 right so let's say we", 'TimeStamp': 832.399},
#   {'Text': 'retrieve five documents so these', 'TimeStamp': 837.0},
#   {'Text': 'documents now have the context so', 'TimeStamp': 839.88},
#   {'Text': 'remember i showed you example how do i', 'TimeStamp': 844.199},
#   {'Text': 'enroll in the course or how like is it', 'TimeStamp': 845.639},
#   {'Text': 'too late to join the course the llm has', 'TimeStamp': 847.959},
#   {'Text': 'no idea but now these documents they', 'TimeStamp': 850.399},
#   {'Text': 'provide the context for llm to figure', 'TimeStamp': 853.44},
#   {'Text': 'out the right answer so now using the', 'TimeStamp': 856.24},
#   {'Text': 'documents we do a prompt we create a', 'TimeStamp': 859.16},
#   {'Text': 'prompt so let me just reuse uh this', 'TimeStamp': 863.44},
#   {'Text': 'prompt so now we put this prompt and the', 'TimeStamp': 866.92},
#   {'Text': 'context', 'TimeStamp': 870.36},
#   {'Text': 'becomes uh these documents', 'TimeStamp': 871.72},
#   {'Text': 'd1 etc d5 right so these are the', 'TimeStamp': 875.0},
#   {'Text': 'documents we received and now we send', 'TimeStamp': 878.759},
#   {'Text': 'this', 'TimeStamp': 881.68},
#   {'Text': 'prompt to the', 'TimeStamp': 883.0},
#   {'Text': 'llm so llm receives the prompt it has', 'TimeStamp': 887.72},
#   {'Text': 'the question it has the context and now', 'TimeStamp': 891.519},
#   {'Text': 'based on the question and the context it', 'TimeStamp': 894.12},
#   {'Text': 'can generate answer which we now', 'TimeStamp': 895.959},
#   {'Text': 'we return to the user so this is the', 'TimeStamp': 899.56},
#   {'Text': 'answer we', 'TimeStamp': 903.12},
#   {'Text': 'sent so this is what i call the raack', 'TimeStamp': 905.639},
#   {'Text': 'framework like how exactly we use a', 'TimeStamp': 910.04},
#   {'Text': 'database knowledge base we can just call', 'TimeStamp': 914.04},
#   {'Text': 'it database and lm together in order to', 'TimeStamp': 916.72},
#   {'Text': 'accomplish what we want here how do we', 'TimeStamp': 920.68},
#   {'Text': 'add context to our queries right so this', 'TimeStamp': 922.92},
#   {'Text': 'is the rack framework and', 'TimeStamp': 926.48},
#   {'Text': 'actually this database and this llm can', 'TimeStamp': 930.48},
#   {'Text': 'be anything so for example in the course', 'TimeStamp': 933.519},
#   {'Text': 'in this particular module we first will', 'TimeStamp': 936.519},
#   {'Text': 'use a toy search engine like it will be', 'TimeStamp': 939.6},
#   {'Text': 'a super simple search engine just to', 'TimeStamp': 941.92},
#   {'Text': 'illustrate the idea but then later in', 'TimeStamp': 943.68},
#   {'Text': 'the same module we will replace this', 'TimeStamp': 946.04},
#   {'Text': 'search engine with elastic search and', 'TimeStamp': 947.959},
#   {'Text': 'later in the course we will replace uh', 'TimeStamp': 950.8},
#   {'Text': 'we will not just use text search but we', 'TimeStamp': 953.079},
#   {'Text': 'will use some other uh ways of searching', 'TimeStamp': 955.68},
#   {'Text': 'in particular vector search so this', 'TimeStamp': 959.12},
#   {'Text': 'thing here it can be anything like it', 'TimeStamp': 961.399},
#   {'Text': "doesn't have to be one specific", 'TimeStamp': 963.319},
#   {'Text': 'technology in this framework you can', 'TimeStamp': 965.319},
#   {'Text': 'easily replace them with another tool', 'TimeStamp': 967.56},
#   {'Text': 'and see what works better and the same', 'TimeStamp': 971.44},
#   {'Text': 'goes with llm so in this module we will', 'TimeStamp': 973.72},
#   {'Text': "use open ai but it doesn't have to be", 'TimeStamp': 976.16},
#   {'Text': 'open ai you can use some open source llm', 'TimeStamp': 978.72},
#   {'Text': 'and you just replace one with another', 'TimeStamp': 981.72},
#   {'Text': 'you will of course need to tweak the', 'TimeStamp': 983.92},
#   {'Text': 'prompt because different lamps expect', 'TimeStamp': 985.6},
#   {'Text': 'the like they they want the prompts to', 'TimeStamp': 988.44},
#   {'Text': 'be a little bit different', 'TimeStamp': 990.6},
#   {'Text': "and that's all so we have the framework", 'TimeStamp': 993.8},
#   {'Text': 'we replace uh or we put we insert some', 'TimeStamp': 997.839},
#   {'Text': 'particular database some particular uh', 'TimeStamp': 1001.72},
#   {'Text': 'llm we see how it works and then at the', 'TimeStamp': 1004.68},
#   {'Text': 'end of the course we will also put this', 'TimeStamp': 1008.199},
#   {'Text': 'in some nice ui like stream le or', 'TimeStamp': 1010.6},
#   {'Text': 'something like that so this is what you', 'TimeStamp': 1012.759},
#   {'Text': 'are going to learn and this is what', 'TimeStamp': 1014.399},
#   {'Text': "you're are going to do and then at the", 'TimeStamp': 1015.839},
#   {'Text': 'end of the course you will implement', 'TimeStamp': 1017.519},
#   {'Text': 'something like that on your own', 'TimeStamp': 1019.36},
#   {'Text': "knowledge base so i'm really looking", 'TimeStamp': 1021.12},
#   {'Text': 'forward to the course and uh yeah have', 'TimeStamp': 1024.16},
#   {'Text': "fun and uh yeah next we'll talk about uh", 'TimeStamp': 1027.76},
#   {'Text': 'preparing the environment', 'TimeStamp': 1033.0}],
#  'llm zoomcamp 1.2 - configuring your environment': [{'Text': 'hi everyone in this video i want to show',
#    'TimeStamp': 0.24},
#   {'Text': 'you how to configure your environment in', 'TimeStamp': 2.12},
#   {'Text': 'this particular video i want to use', 'TimeStamp': 5.359},
#   {'Text': 'github codes spaces to show how to', 'TimeStamp': 6.96},
#   {'Text': "configure it but you don't have to use", 'TimeStamp': 8.519},
#   {'Text': 'it you can just follow along the video', 'TimeStamp': 10.32},
#   {'Text': 'and do everything you need on your local', 'TimeStamp': 13.519},
#   {'Text': 'machine i will not show how to install', 'TimeStamp': 15.48},
#   {'Text': 'docker you will need to do it yourself', 'TimeStamp': 17.48},
#   {'Text': 'because cod spaces already has', 'TimeStamp': 20.48},
#   {'Text': 'docker and we will focus on installing', 'TimeStamp': 22.599},
#   {'Text': 'uh the libraries we need for this', 'TimeStamp': 26.92},
#   {'Text': 'particular model', 'TimeStamp': 28.76},
#   {'Text': 'or you can like you again as i said you', 'TimeStamp': 31.519},
#   {'Text': "don't have to use cod spaces it's a very", 'TimeStamp': 33.879},
#   {'Text': 'convenient tool but you can also for', 'TimeStamp': 35.96},
#   {'Text': 'this model you can use g collab google', 'TimeStamp': 37.6},
#   {'Text': 'collab you can use c cloud uh you can', 'TimeStamp': 40.84},
#   {'Text': 'use any other notebook provider like', 'TimeStamp': 44.559},
#   {'Text': 'sage maker or you can just run things', 'TimeStamp': 47.559},
#   {'Text': 'locally for the uh second module we will', 'TimeStamp': 50.559},
#   {'Text': "need a gpu right now we don't need your", 'TimeStamp': 53.28},
#   {'Text': 'gpu for the second module we will so if', 'TimeStamp': 55.359},
#   {'Text': 'you have an access to a machine with gpu', 'TimeStamp': 57.8},
#   {'Text': "it's good you should use that if you", 'TimeStamp': 60.32},
#   {'Text': "don't uh then this is something we will", 'TimeStamp': 63.359},
#   {'Text': 'talk about in the in the next module', 'TimeStamp': 65.92},
#   {'Text': 'right now back to cod spaces i will show', 'TimeStamp': 68.439},
#   {'Text': 'you how to set up a simple uh', 'TimeStamp': 70.84},
#   {'Text': "environment from scratch and it's free", 'TimeStamp': 73.32},
#   {'Text': 'so you should go to your github account', 'TimeStamp': 76.28},
#   {'Text': 'create a new', 'TimeStamp': 78.84},
#   {'Text': "repository uh give it some name so i'll", 'TimeStamp': 79.92},
#   {'Text': 'call it', 'TimeStamp': 82.24},
#   {'Text': 'llm zoom', 'TimeStamp': 83.52},
#   {'Text': 'camp and um it should be public because', 'TimeStamp': 85.96},
#   {'Text': 'uh like you will um commit your', 'TimeStamp': 90.119},
#   {'Text': 'notebooks uh your homeworks here um and', 'TimeStamp': 93.84},
#   {'Text': 'then you will need to share the link to', 'TimeStamp': 97.32},
#   {'Text': 'the homework in the answers uh in the', 'TimeStamp': 98.96},
#   {'Text': 'answer for so make it private and then', 'TimeStamp': 101.84},
#   {'Text': "uh so license we don't care about the", 'TimeStamp': 105.6},
#   {'Text': 'license g ignore should be python so', 'TimeStamp': 108.28},
#   {'Text': "let's create a", 'TimeStamp': 111.24},
#   {'Text': 'repository and once the rep is created', 'TimeStamp': 112.439},
#   {'Text': 'we click on code and there are two tabs', 'TimeStamp': 115.0},
#   {'Text': 'here local and code spaces i just click', 'TimeStamp': 117.039},
#   {'Text': 'on create a code space online right now', 'TimeStamp': 120.079},
#   {'Text': 'it will start visual studio code in a', 'TimeStamp': 123.039},
#   {'Text': 'browser so it is preparing the', 'TimeStamp': 125.92},
#   {'Text': "environment uh we don't want to use the", 'TimeStamp': 128.319},
#   {'Text': 'browser so i already have visual studio', 'TimeStamp': 130.44},
#   {'Text': 'desktop um on my computer you should', 'TimeStamp': 132.959},
#   {'Text': 'also have it if you want to follow uh', 'TimeStamp': 136.92},
#   {'Text': "along uh this tutorial again you don't", 'TimeStamp': 139.2},
#   {'Text': 'have to do this if you already have the', 'TimeStamp': 141.519},
#   {'Text': "tools we're going to install later you", 'TimeStamp': 144.4},
#   {'Text': 'should be fine so now let me open it uh', 'TimeStamp': 147.08},
#   {'Text': 'on visual studio code desktop so i', 'TimeStamp': 151.08},
#   {'Text': 'clicked here and i click on open inv', 'TimeStamp': 153.08},
#   {'Text': 'this code', 'TimeStamp': 155.44},
#   {'Text': 'desktop and right now visual studio code', 'TimeStamp': 157.56},
#   {'Text': "if it's the first time you uh run cod", 'TimeStamp': 161.2},
#   {'Text': 'spaces it should after some time should', 'TimeStamp': 164.28},
#   {'Text': 'ask you to to install an extension for', 'TimeStamp': 168.159},
#   {'Text': "cod spaces if it doesn't you will need", 'TimeStamp': 171.879},
#   {'Text': 'to do this manually you go to extensions', 'TimeStamp': 174.599},
#   {'Text': 'and you type code spaces here', 'TimeStamp': 177.4},
#   {'Text': 'yeah so this one you will need to', 'TimeStamp': 181.159},
#   {'Text': "install it i already have it so i don't", 'TimeStamp': 182.92},
#   {'Text': 'need to install it and actually we', 'TimeStamp': 185.159},
#   {'Text': 'already have a code space enabled in', 'TimeStamp': 189.28},
#   {'Text': 'accessible in our visual studio code', 'TimeStamp': 192.64},
#   {'Text': 'desktop and i just pressed contrl tilda', 'TimeStamp': 195.48},
#   {'Text': 'to open the command line and here we', 'TimeStamp': 198.799},
#   {'Text': 'have already have docker can run hello', 'TimeStamp': 201.28},
#   {'Text': 'world so docker docker compose uh are', 'TimeStamp': 206.4},
#   {'Text': 'already here and we have', 'TimeStamp': 210.08},
#   {'Text': "python and um i'll show you two ways of", 'TimeStamp': 212.959},
#   {'Text': 'preparing the environment the first uh', 'TimeStamp': 216.36},
#   {'Text': 'way would be just using the python that', 'TimeStamp': 218.92},
#   {'Text': 'we already have here we will need to', 'TimeStamp': 221.879},
#   {'Text': 'install the libraries we need and then', 'TimeStamp': 223.799},
#   {'Text': "in the second part of the video i'll", 'TimeStamp': 226.72},
#   {'Text': 'show you how to install an aond with', 'TimeStamp': 228.48},
#   {'Text': "anakonda you don't need to install any", 'TimeStamp': 230.08},
#   {'Text': 'libraries you can just download in aa', 'TimeStamp': 232.0},
#   {'Text': "and that's all you need so uh for", 'TimeStamp': 235.04},
#   {'Text': "installing libraries we'll use peep", 'TimeStamp': 238.879},
#   {'Text': 'in in', 'TimeStamp': 241.92},
#   {'Text': "install and then there's a bunch of", 'TimeStamp': 245.439},
#   {'Text': 'libraries we need to install', 'TimeStamp': 247.76},
#   {'Text': "tqdm which is a progress manager it's", 'TimeStamp': 249.4},
#   {'Text': 'very', 'TimeStamp': 253.72},
#   {'Text': 'convenient uh then uh well we will not', 'TimeStamp': 254.439},
#   {'Text': 'need tqdm actually for this particular', 'TimeStamp': 258.72},
#   {'Text': 'module we will need it later uh then we', 'TimeStamp': 260.639},
#   {'Text': "will need jupyter notebook i'll specify", 'TimeStamp': 263.96},
#   {'Text': 'the', 'TimeStamp': 267.0},
#   {'Text': 'version uh the version will will be', 'TimeStamp': 268.08},
#   {'Text': '7.1.2 then we will need open ey to speak', 'TimeStamp': 273.0},
#   {'Text': 'to uh the open ai api and also we will', 'TimeStamp': 277.52},
#   {'Text': 'need um elastic', 'TimeStamp': 283.12},
#   {'Text': 'search so arch right at the end as i', 'TimeStamp': 287.759},
#   {'Text': 'said we will first we will use a simple', 'TimeStamp': 291.36},
#   {'Text': 'toy search engine but then at the end of', 'TimeStamp': 294.52},
#   {'Text': 'the module we will replace it with', 'TimeStamp': 296.28},
#   {'Text': "elastic search and so that's why we need", 'TimeStamp': 297.84},
#   {'Text': 'to install it', 'TimeStamp': 300.639},
#   {'Text': "um i don't know if we need to install", 'TimeStamp': 303.639},
#   {'Text': 'anything else so also i think p', 'TimeStamp': 305.8},
#   {'Text': 'learn uh yeah and', 'TimeStamp': 309.479},
#   {'Text': 'pandas so', 'TimeStamp': 313.4},
#   {'Text': "that's jupiter notebook open elastic s", 'TimeStamp': 316.039},
#   {'Text': 'second learn', 'TimeStamp': 319.319},
#   {'Text': 'pandas when later we use anaconda we', 'TimeStamp': 321.039},
#   {'Text': 'will need to install tqdm openi and', 'TimeStamp': 324.639},
#   {'Text': 'elastic search it already has jupiter it', 'TimeStamp': 327.52},
#   {'Text': 'already has psy it already has', 'TimeStamp': 330.039},
#   {'Text': 'pandas and then i made a type', 'TimeStamp': 333.479},
#   {'Text': 'elastic search ltic', 'TimeStamp': 338.759},
#   {'Text': 'search hopefully it should work', 'TimeStamp': 344.28},
#   {'Text': 'now so many t sorry', 'TimeStamp': 348.199},
#   {'Text': 'about so did i make a typo did i make it', 'TimeStamp': 353.28},
#   {'Text': 'typo again no this time it was actually', 'TimeStamp': 356.319},
#   {'Text': 'good', 'TimeStamp': 359.44},
#   {'Text': 'and while we are installing it uh we', 'TimeStamp': 360.52},
#   {'Text': 'will need to have a key for open ai', 'TimeStamp': 363.16},
#   {'Text': "because we will use it it's llm", 'TimeStamp': 366.919},
#   {'Text': 'gpd so i will go', 'TimeStamp': 369.96},
#   {'Text': 'to uh platform.', 'TimeStamp': 373.16},
#   {'Text': 'open.com you should uh register there if', 'TimeStamp': 376.08},
#   {'Text': "you haven't and this is sort of semi", 'TimeStamp': 379.16},
#   {'Text': 'optional we will also show how to run it', 'TimeStamp': 382.4},
#   {'Text': 'without openi but for simplicity and', 'TimeStamp': 386.16},
#   {'Text': 'also for this model', 'TimeStamp': 388.72},
#   {'Text': 'you should have an uh you should have an', 'TimeStamp': 390.16},
#   {'Text': 'account', 'TimeStamp': 393.88},
#   {'Text': 'there', 'TimeStamp': 394.96},
#   {'Text': 'then we need to go', 'TimeStamp': 396.8},
#   {'Text': 'to api', 'TimeStamp': 399.16},
#   {'Text': "keys and i'm going to create a new api", 'TimeStamp': 401.24},
#   {'Text': "key i'll call it um", 'TimeStamp': 404.199},
#   {'Text': "course and i'll create a secret key i", 'TimeStamp': 408.16},
#   {'Text': 'will remove this key of course after', 'TimeStamp': 411.52},
#   {'Text': "recording this video i don't want you to", 'TimeStamp': 413.599},
#   {'Text': 'use it of course so but right now you', 'TimeStamp': 417.0},
#   {'Text': 'will see my key but this should never', 'TimeStamp': 420.68},
#   {'Text': 'ever happen like you do not you have to', 'TimeStamp': 423.479},
#   {'Text': 'watch your key and never ever expose it', 'TimeStamp': 427.56},
#   {'Text': 'commit it to g or uh show it to', 'TimeStamp': 429.919},
#   {'Text': "anyone show it to people you don't trust", 'TimeStamp': 433.919},
#   {'Text': 'so now we need to take the key and now i', 'TimeStamp': 437.4},
#   {'Text': 'write', 'TimeStamp': 440.56},
#   {'Text': 'expert open', 'TimeStamp': 441.8},
#   {'Text': 'ai api', 'TimeStamp': 444.4},
#   {'Text': 'key and then i copy the key so now we', 'TimeStamp': 446.599},
#   {'Text': 'have the key in our environment and i', 'TimeStamp': 450.56},
#   {'Text': 'just start', 'TimeStamp': 452.919},
#   {'Text': 'jitter', 'TimeStamp': 454.759},
#   {'Text': 'notbook so notbook is starting and if', 'TimeStamp': 461.039},
#   {'Text': 'you run in code spaces like me you', 'TimeStamp': 464.759},
#   {'Text': 'should notice that this port', 'TimeStamp': 467.52},
#   {'Text': 'ports um tap got one so it means that uh', 'TimeStamp': 470.0},
#   {'Text': 'it detected that there is a port', 'TimeStamp': 475.36},
#   {'Text': '8888 that is running on the cod spaces', 'TimeStamp': 477.759},
#   {'Text': 'and it forwarded automatically forwarded', 'TimeStamp': 480.759},
#   {'Text': 'this port to our local machine which', 'TimeStamp': 483.28},
#   {'Text': 'means that now we can use our browser to', 'TimeStamp': 485.24},
#   {'Text': 'access the jupyter', 'TimeStamp': 488.759},
#   {'Text': "notebook i'll just type local host", 'TimeStamp': 490.919},
#   {'Text': '8888 and yeah it asks for', 'TimeStamp': 494.68},
#   {'Text': 'token we can just copy this whole thing', 'TimeStamp': 497.44},
#   {'Text': 'or if the port is different for you you', 'TimeStamp': 500.319},
#   {'Text': 'can copy this', 'TimeStamp': 502.56},
#   {'Text': 'token so maybe you already have jupiter', 'TimeStamp': 505.84},
#   {'Text': 'running and then the would be 8888 9', 'TimeStamp': 508.24},
#   {'Text': "something like that i don't know if i", 'TimeStamp': 511.56},
#   {'Text': 'how many eights i said anyways um so we', 'TimeStamp': 514.76},
#   {'Text': 'have jupiter now i just click new python', 'TimeStamp': 518.36},
#   {'Text': '3 it will automatically open', 'TimeStamp': 522.12},
#   {'Text': 'it and let me make it', 'TimeStamp': 525.0},
#   {'Text': "large i'll hide h here and then we can", 'TimeStamp': 528.36},
#   {'Text': "just test that things work so i'll", 'TimeStamp': 532.32},
#   {'Text': 'import open', 'TimeStamp': 534.6},
#   {'Text': 'ai so', 'TimeStamp': 537.88},
#   {'Text': 'works and now we can send a simple', 'TimeStamp': 540.279},
#   {'Text': 'request to open ai um', 'TimeStamp': 543.88},
#   {'Text': 'so check the', 'TimeStamp': 547.16},
#   {'Text': 'code actually we do it from open ai', 'TimeStamp': 552.12},
#   {'Text': 'import open', 'TimeStamp': 556.16},
#   {'Text': 'ai create a', 'TimeStamp': 562.04},
#   {'Text': '[music]', 'TimeStamp': 563.72},
#   {'Text': 'client and here when we create a client', 'TimeStamp': 564.959},
#   {'Text': 'we can provide the api key', 'TimeStamp': 567.68},
#   {'Text': 'explicitly here by saying', 'TimeStamp': 570.04},
#   {'Text': 'api um key and then this is the key that', 'TimeStamp': 572.16},
#   {'Text': 'i', 'TimeStamp': 577.72},
#   {'Text': 'have is the', 'TimeStamp': 578.8},
#   {'Text': 'key i think i should start with sk', 'TimeStamp': 581.56},
#   {'Text': 'whatever', 'TimeStamp': 585.32},
#   {'Text': "um uh i'm just wondering what did i put", 'TimeStamp': 587.56},
#   {'Text': 'here cu typically the key starts with um', 'TimeStamp': 592.2},
#   {'Text': 'sk something', 'TimeStamp': 596.56},
#   {'Text': 'um yeah i will not try to find it here', 'TimeStamp': 601.959},
#   {'Text': 'anyways so we put the key like that or', 'TimeStamp': 606.04},
#   {'Text': "if we don't provide it it will read it", 'TimeStamp': 608.88},
#   {'Text': 'from the uh from the environmental', 'TimeStamp': 612.2},
#   {'Text': 'variable that we created um we can', 'TimeStamp': 614.959},
#   {'Text': 'quickly check if actually i did that so', 'TimeStamp': 617.68},
#   {'Text': 'we import os os m', 'TimeStamp': 620.399},
#   {'Text': 'creates see', 'TimeStamp': 628.2},
#   {'Text': "i think it's", 'TimeStamp': 637.12},
#   {'Text': 's in environment yeah so here we', 'TimeStamp': 639.36},
#   {'Text': 'have um we should have open i key yeah', 'TimeStamp': 644.079},
#   {'Text': 'so this is the key so this is the right', 'TimeStamp': 647.76},
#   {'Text': 'key and we can put the key directly or', 'TimeStamp': 649.6},
#   {'Text': 'if we set up this', 'TimeStamp': 654.399},
#   {'Text': 'um um this environmental variable we', 'TimeStamp': 656.36},
#   {'Text': "don't need to do anything so we just do", 'TimeStamp': 658.959},
#   {'Text': 'cent client initialize the client it', 'TimeStamp': 661.32},
#   {'Text': 'looks up the key in the environmental', 'TimeStamp': 664.04},
#   {'Text': 'variables and uses', 'TimeStamp': 666.24},
#   {'Text': 'it right so we have the client and now', 'TimeStamp': 668.44},
#   {'Text': 'we can say that we want to use', 'TimeStamp': 671.2},
#   {'Text': 'chat um chat', 'TimeStamp': 674.72},
#   {'Text': 'api uh like that and we can specify the', 'TimeStamp': 677.88},
#   {'Text': 'model we want to use so for example if', 'TimeStamp': 683.6},
#   {'Text': 'we go here to playground can see what', 'TimeStamp': 686.24},
#   {'Text': 'kind of models they have right so we can', 'TimeStamp': 689.32},
#   {'Text': 'just say we want to use gpt', 'TimeStamp': 692.16},
#   {'Text': '40 gpt for', 'TimeStamp': 695.519},
#   {'Text': 'all and', 'TimeStamp': 698.92},
#   {'Text': 'message messages is what we want to', 'TimeStamp': 701.92},
#   {'Text': "write to the client so let's", 'TimeStamp': 704.399},
#   {'Text': 'say yeah so we need to specify the role', 'TimeStamp': 709.6},
#   {'Text': 'uh there are multiple roles like user', 'TimeStamp': 713.16},
#   {'Text': 'and system we will not go into details', 'TimeStamp': 715.24},
#   {'Text': 'right now so user is like when in char', 'TimeStamp': 718.04},
#   {'Text': 'gpt i type something so the role is user', 'TimeStamp': 721.32},
#   {'Text': 'for me so this', 'TimeStamp': 725.519},
#   {'Text': 'is exactly what i did when i typed uh', 'TimeStamp': 727.2},
#   {'Text': 'when i opened gbt in the intro video', 'TimeStamp': 730.44},
#   {'Text': 'chbt and typed um how do i cook', 'TimeStamp': 732.92},
#   {'Text': 'salmon and then content is', 'TimeStamp': 736.76},
#   {'Text': 'uh let me write um something', 'TimeStamp': 741.32},
#   {'Text': 'like is it too late to join the', 'TimeStamp': 746.32},
#   {'Text': "course then let's save it to", 'TimeStamp': 753.959},
#   {'Text': 'response and then see what is the reply', 'TimeStamp': 758.639},
#   {'Text': 'and the reply', 'TimeStamp': 761.519},
#   {'Text': "is yeah there's a bunch of things but we", 'TimeStamp': 763.399},
#   {'Text': 'can say', 'TimeStamp': 766.36},
#   {'Text': 'choices so there are there is only one', 'TimeStamp': 768.199},
#   {'Text': 'choice right and then the message', 'TimeStamp': 770.639},
#   {'Text': 'inside the choices is this one or we can', 'TimeStamp': 774.959},
#   {'Text': 'just show the', 'TimeStamp': 779.279},
#   {'Text': '[music]', 'TimeStamp': 780.32},
#   {'Text': 'content doing it this way so and then', 'TimeStamp': 782.639},
#   {'Text': 'this is the answer right so of course it', 'TimeStamp': 785.839},
#   {'Text': "has no idea what course i'm referring", 'TimeStamp': 788.56},
#   {'Text': 'to therefore it provides this answer now', 'TimeStamp': 790.56},
#   {'Text': "i'll show you a different way to prepare", 'TimeStamp': 794.639},
#   {'Text': 'the environment so this is kind of', 'TimeStamp': 796.04},
#   {'Text': 'enough but if you want to see how to do', 'TimeStamp': 798.639},
#   {'Text': "it with anaconda it's a little bit", 'TimeStamp': 800.72},
#   {'Text': 'easier anaconda install', 'TimeStamp': 803.959},
#   {'Text': 'linux then uh we have this link docs', 'TimeStamp': 807.0},
#   {'Text': 'andaconda free andaconda install linux', 'TimeStamp': 811.76},
#   {'Text': 'and then there is a url that we need to', 'TimeStamp': 814.639},
#   {'Text': 'execute to to have and we can see the', 'TimeStamp': 818.079},
#   {'Text': 'full list of installers available at', 'TimeStamp': 821.519},
#   {'Text': "this link and i'll just", 'TimeStamp': 823.68},
#   {'Text': 'pick this is the probably the latest', 'TimeStamp': 825.92},
#   {'Text': 'one notice that this is actually quite', 'TimeStamp': 830.12},
#   {'Text': "large so it's almost 1 gab uh cuz like", 'TimeStamp': 833.079},
#   {'Text': "there's a lot of stuff in anaconda and", 'TimeStamp': 836.68},
#   {'Text': "most of it we frankly don't need but for", 'TimeStamp': 838.36},
#   {'Text': "simplicity like it's very simple we just", 'TimeStamp': 841.72},
#   {'Text': 'download unpack it and can use it um so', 'TimeStamp': 843.68},
#   {'Text': 'i copy the', 'TimeStamp': 848.199},
#   {'Text': "link and i'll stop right now", 'TimeStamp': 850.36},
#   {'Text': "jupiter and i'll do w get um i'll go one", 'TimeStamp': 855.199},
#   {'Text': "one level up so i don't download an aa", 'TimeStamp': 859.6},
#   {'Text': 'in my', 'TimeStamp': 862.36},
#   {'Text': 'workspace uh i do w get and then this', 'TimeStamp': 863.88},
#   {'Text': 'path so now i download it and i will now', 'TimeStamp': 867.759},
#   {'Text': 'unpack', 'TimeStamp': 871.759},
#   {'Text': 'it you can also instead of using', 'TimeStamp': 872.959},
#   {'Text': 'anaconda you can use miniconda maybe', 'TimeStamp': 875.16},
#   {'Text': "i'll show you too how to do this", 'TimeStamp': 877.68},
#   {'Text': 'mini uh install', 'TimeStamp': 881.759},
#   {'Text': 'linux and this is', 'TimeStamp': 885.8},
#   {'Text': 'actually the same we just need to find', 'TimeStamp': 888.16},
#   {'Text': 'um any installer for linux we just need', 'TimeStamp': 892.199},
#   {'Text': 'to find where yeah this is the latest so', 'TimeStamp': 895.8},
#   {'Text': 'they also have this repo this is the', 'TimeStamp': 899.639},
#   {'Text': 'same url as we used', 'TimeStamp': 901.8},
#   {'Text': 'previously', 'TimeStamp': 903.72},
#   {'Text': "um so let's use this one with python", 'TimeStamp': 905.6},
#   {'Text': '3.10 for linux', 'TimeStamp': 910.24},
#   {'Text': 'uh this architecture so will copy the', 'TimeStamp': 913.759},
#   {'Text': "link and notice that it's way", 'TimeStamp': 917.399},
#   {'Text': "smaller this link so it's way smaller", 'TimeStamp': 920.92},
#   {'Text': 'than what we had so just do all we yet', 'TimeStamp': 924.68},
#   {'Text': "and let's install miniconda but for", 'TimeStamp': 929.12},
#   {'Text': "anaconda it's the same you do bash", 'TimeStamp': 930.959},
#   {'Text': 'minond and then you read the', 'TimeStamp': 934.839},
#   {'Text': "agreement it's becoming longer and", 'TimeStamp': 940.6},
#   {'Text': 'longer yeah come', 'TimeStamp': 945.639},
#   {'Text': 'on yeah i accept because i read very', 'TimeStamp': 949.8},
#   {'Text': 'carefully so now we install uh minondo', 'TimeStamp': 953.12},
#   {'Text': 'and with an aon would be the same just', 'TimeStamp': 961.36},
#   {'Text': 'would take a bit little bit longer we', 'TimeStamp': 963.399},
#   {'Text': 'initialize it and now when i create a', 'TimeStamp': 965.56},
#   {'Text': 'new', 'TimeStamp': 969.56},
#   {'Text': 'shell we have base here here meaning', 'TimeStamp': 970.88},
#   {'Text': 'that we ed the base environment and now', 'TimeStamp': 975.279},
#   {'Text': 'we can use which python to see to see', 'TimeStamp': 978.24},
#   {'Text': 'where the python comes from so the', 'TimeStamp': 982.72},
#   {'Text': 'python comes from minond and when we do', 'TimeStamp': 984.959},
#   {'Text': 'python minus v so this is a python from', 'TimeStamp': 987.24},
#   {'Text': 'miniconda so this could be convenient if', 'TimeStamp': 989.88},
#   {'Text': "you're are not running on u cod", 'TimeStamp': 991.88},
#   {'Text': "spaces um but let's now when we do which", 'TimeStamp': 995.16},
#   {'Text': 'pip we can install the same things we', 'TimeStamp': 1001.079},
#   {'Text': "installed previously and if it's", 'TimeStamp': 1003.92},
#   {'Text': "miniconda or if it's anakonda you don't", 'TimeStamp': 1005.88},
#   {'Text': "need to install jupiter you don't need", 'TimeStamp': 1008.12},
#   {'Text': 'to install', 'TimeStamp': 1010.0},
#   {'Text': "um second lear you don't need to install", 'TimeStamp': 1012.48},
#   {'Text': 'pandas just elastic search open ai and', 'TimeStamp': 1015.279},
#   {'Text': 'tqdm', 'TimeStamp': 1017.16},
#   {'Text': "i think that's enough for this so now", 'TimeStamp': 1019.04},
#   {'Text': 'you know how to prepare the environment', 'TimeStamp': 1020.6},
#   {'Text': "uh maybe just last thing um i'll show", 'TimeStamp': 1022.8},
#   {'Text': 'you how to commit your changes so this', 'TimeStamp': 1025.64},
#   {'Text': "is the file we worked on let's say this", 'TimeStamp': 1028.079},
#   {'Text': 'is your homework of course give it a', 'TimeStamp': 1029.839},
#   {'Text': 'meaningful name uh we can create a new', 'TimeStamp': 1031.919},
#   {'Text': 'like create a proper directory for this', 'TimeStamp': 1035.919},
#   {'Text': 'uh 0 one', 'TimeStamp': 1039.64},
# ...
#   {'Text': 'stop right', 'TimeStamp': 2571.16},
#   {'Text': "yeah i'm just trying to figure out what", 'TimeStamp': 2583.92},
#   {'Text': 'i need to', 'TimeStamp': 2586.359},
#   {'Text': 'copy so first is the', 'TimeStamp': 2588.559},
#   {'Text': 'query and next is this', 'TimeStamp': 2593.119},
#   {'Text': 'thing okay so i think what happened is', 'TimeStamp': 2599.96},
#   {'Text': 'just it deleted one of these', 'TimeStamp': 2603.04},
#   {'Text': 'things i think i also did deleted', 'TimeStamp': 2605.24},
#   {'Text': 'it what is', 'TimeStamp': 2615.52},
#   {'Text': 'that yeah okay now it works and it', 'TimeStamp': 2618.52},
#   {'Text': 'should save the data to uh', 'TimeStamp': 2622.2},
#   {'Text': 'postgress um well ideally i should go', 'TimeStamp': 2626.119},
#   {'Text': 'and check but i think it works right so', 'TimeStamp': 2629.76},
#   {'Text': 'we will see later when we set up grafana', 'TimeStamp': 2633.559},
#   {'Text': 'that it actually works', 'TimeStamp': 2636.28},
#   {'Text': 'um okay so this one works now we just', 'TimeStamp': 2638.88},
#   {'Text': 'need to implement safe', 'TimeStamp': 2643.72},
#   {'Text': 'feedback dp', 'TimeStamp': 2653.88},
#   {'Text': 'safe db safe', 'TimeStamp': 2656.24},
#   {'Text': 'feedback okay', 'TimeStamp': 2663.2},
#   {'Text': 'i will now execute this', 'TimeStamp': 2670.119},
#   {'Text': 'thing id will', 'TimeStamp': 2678.92},
#   {'Text': 'be', 'TimeStamp': 2683.24},
#   {'Text': 'this and let me execute it this way', 'TimeStamp': 2690.599},
#   {'Text': 'what is wrong uh yeah', 'TimeStamp': 2698.96},
#   {'Text': "maybe url let's put here for", 'TimeStamp': 2702.4},
#   {'Text': 'completeness cool so now it works we can', 'TimeStamp': 2714.04},
#   {'Text': 'save uh the logs and we can save the', 'TimeStamp': 2718.119},
#   {'Text': 'feedback uh using this', 'TimeStamp': 2721.88},
#   {'Text': 'okay so what else we need to do here so', 'TimeStamp': 2727.8},
#   {'Text': 'it kind of works more or less we just', 'TimeStamp': 2730.96},
#   {'Text': 'need to make sure that these things that', 'TimeStamp': 2733.119},
#   {'Text': 'we', 'TimeStamp': 2735.4},
#   {'Text': 'return are good and for that we need', 'TimeStamp': 2736.28},
#   {'Text': "to to also implement that right so i'll", 'TimeStamp': 2741.96},
#   {'Text': 'go back to the zoom', 'TimeStamp': 2744.64},
#   {'Text': 'camp', 'TimeStamp': 2747.24},
#   {'Text': 'and where is the app assistant i think', 'TimeStamp': 2749.44},
#   {'Text': 'this is where', 'TimeStamp': 2753.88},
#   {'Text': 'we implement all the things', 'TimeStamp': 2755.24},
#   {'Text': 'right so evate relevance uh so first of', 'TimeStamp': 2761.359},
#   {'Text': "all let's go to", 'TimeStamp': 2765.72},
#   {'Text': 'llm and', 'TimeStamp': 2767.72},
#   {'Text': 'also so answer tokens', 'TimeStamp': 2774.44},
#   {'Text': 'yeah go to the', 'TimeStamp': 2788.48},
#   {'Text': 'llm and we have the answer we have', 'TimeStamp': 2791.52},
#   {'Text': 'tokens and this will be the', 'TimeStamp': 2795.2},
#   {'Text': 'response answer', 'TimeStamp': 2797.839},
#   {'Text': 'tokens or token', 'TimeStamp': 2805.319},
#   {'Text': "stats it's", 'TimeStamp': 2808.92},
#   {'Text': "better and right now let's find where we", 'TimeStamp': 2812.0},
#   {'Text': 'use lm in just one place', 'TimeStamp': 2814.88},
#   {'Text': 'this token', 'TimeStamp': 2818.2},
#   {'Text': 'stats so token starts', 'TimeStamp': 2823.559},
#   {'Text': 'uh', 'TimeStamp': 2827.48},
#   {'Text': 'here is it right from tokens completion', 'TimeStamp': 2829.559},
#   {'Text': 'tokens total tokens', 'TimeStamp': 2833.48},
#   {'Text': 'okay token sts', 'TimeStamp': 2836.359},
#   {'Text': 'completion tokens and total', 'TimeStamp': 2848.24},
#   {'Text': 'tokens um okay now we have uh prom', 'TimeStamp': 2861.04},
#   {'Text': 'tokens and uh completion tokens for', 'TimeStamp': 2864.599},
#   {'Text': 'evaluation right so we want to also', 'TimeStamp': 2867.599},
#   {'Text': 'evaluate the results', 'TimeStamp': 2869.44},
#   {'Text': "and the response time it's the the", 'TimeStamp': 2877.559},
#   {'Text': 'entire thing right so i want to include', 'TimeStamp': 2880.0},
#   {'Text': 'everything', 'TimeStamp': 2882.119},
#   {'Text': 'here also', 'TimeStamp': 2883.52},
#   {'Text': 'evaluation so how do we evaluate', 'TimeStamp': 2888.079},
#   {'Text': 'evaluate', 'TimeStamp': 2891.88},
#   {'Text': 'relevance i will now take the prompt', 'TimeStamp': 2898.52},
#   {'Text': 'from', 'TimeStamp': 2900.92},
#   {'Text': 'our our prompt not the one from the', 'TimeStamp': 2904.0},
#   {'Text': 'course', 'TimeStamp': 2906.48},
#   {'Text': 'we have it', 'TimeStamp': 2910.079},
#   {'Text': 'here in this', 'TimeStamp': 2911.52},
#   {'Text': 'thing you need to', 'TimeStamp': 2917.68},
#   {'Text': 'scroll here you', 'TimeStamp': 2919.72},
#   {'Text': 'go so this is the', 'TimeStamp': 2922.92},
#   {'Text': 'prompt i will just copy it and paste it', 'TimeStamp': 2928.28},
#   {'Text': 'here i want to put it outside', 'TimeStamp': 2934.16},
#   {'Text': "so it kind of doesn't look", 'TimeStamp': 2937.359},
#   {'Text': 'messy uh prompt evaluation prompt', 'TimeStamp': 2941.0},
#   {'Text': 'template so here evolation prom', 'TimeStamp': 2946.4},
#   {'Text': 'template', 'TimeStamp': 2951.64},
#   {'Text': 'uh so it will be gpt model gpt for o', 'TimeStamp': 2955.04},
#   {'Text': 'mini for', 'TimeStamp': 2959.68},
#   {'Text': 'revolation i need to import json', 'TimeStamp': 2963.799},
#   {'Text': 'okay evolation tokens then', 'TimeStamp': 2978.04},
#   {'Text': 'we cool and now we just need', 'TimeStamp': 2984.359},
#   {'Text': 'to let make do it this way j all and so', 'TimeStamp': 2992.64},
#   {'Text': 'why do we need to return so many things', 'TimeStamp': 2998.48},
#   {'Text': 'then this one is already a', 'TimeStamp': 3000.24},
#   {'Text': 'dictionary uh how does it look like so', 'TimeStamp': 3006.68},
#   {'Text': 'it should', 'TimeStamp': 3009.16},
#   {'Text': 'be', 'TimeStamp': 3010.24},
#   {'Text': 'result okay like', 'TimeStamp': 3014.48},
#   {'Text': 'that and jon well yeah i like this way', 'TimeStamp': 3020.079},
#   {'Text': "it's just two parameters not three", 'TimeStamp': 3024.16},
#   {'Text': '[music]', 'TimeStamp': 3027.53},
#   {'Text': 'um here evalate', 'TimeStamp': 3029.4},
#   {'Text': 'relevance question and', 'TimeStamp': 3034.72},
#   {'Text': 'answer and the results will', 'TimeStamp': 3037.2},
#   {'Text': 'be', 'TimeStamp': 3042.119},
#   {'Text': 'relevant and then real starts', 'TimeStamp': 3045.52},
#   {'Text': 'um it is relevance', 'TimeStamp': 3058.0},
#   {'Text': 'right', 'TimeStamp': 3064.119},
#   {'Text': 'and or actually we need to make sure', 'TimeStamp': 3068.319},
#   {'Text': 'that these things uh are', 'TimeStamp': 3070.52},
#   {'Text': 'there', 'TimeStamp': 3073.16},
#   {'Text': "um yeah i don't know like probably it", 'TimeStamp': 3075.76},
#   {'Text': 'will fail if relevance is not there when', 'TimeStamp': 3078.68},
#   {'Text': 'it fails to stick to the format we need', 'TimeStamp': 3081.359},
#   {'Text': "i'll probably use", 'TimeStamp': 3087.76},
#   {'Text': 'get and then default value will', 'TimeStamp': 3089.599},
#   {'Text': 'be', 'TimeStamp': 3092.96},
#   {'Text': 'unknown get explanation default value', 'TimeStamp': 3098.88},
#   {'Text': 'will be failed', 'TimeStamp': 3102.359},
#   {'Text': 'to par', 'TimeStamp': 3105.799},
#   {'Text': 'solation okay so now i just need to', 'TimeStamp': 3112.52},
#   {'Text': 'put this thing', 'TimeStamp': 3117.88},
#   {'Text': 'here this', 'TimeStamp': 3120.48},
#   {'Text': 'here', 'TimeStamp': 3123.48},
#   {'Text': 'and this here and then add a', 'TimeStamp': 3125.76},
#   {'Text': "prefix i'll", 'TimeStamp': 3131.359},
#   {'Text': 'starts token starts and then finally the', 'TimeStamp': 3133.599},
#   {'Text': 'cost but that we have a formula', 'TimeStamp': 3140.0},
#   {'Text': 'right where is it', 'TimeStamp': 3143.96},
#   {'Text': 'open', 'TimeStamp': 3148.44},
#   {'Text': 'cost', 'TimeStamp': 3154.92},
#   {'Text': 'um if', 'TimeStamp': 3156.839},
#   {'Text': 'model to', 'TimeStamp': 3159.4},
#   {'Text': 'mini so let me google g', 'TimeStamp': 3173.4},
#   {'Text': 'pt4 or', 'TimeStamp': 3177.72},
#   {'Text': 'mini', 'TimeStamp': 3180.4},
#   {'Text': 'cost this', 'TimeStamp': 3184.16},
#   {'Text': 'one where is the mini one ah', 'TimeStamp': 3192.48},
#   {'Text': 'here can i do it for 1,000 tokens how', 'TimeStamp': 3198.119},
#   {'Text': 'like there is somewhere at toggle i', 'TimeStamp': 3202.64},
#   {'Text': 'think no', 'TimeStamp': 3204.4},
#   {'Text': 'ah', 'TimeStamp': 3207.16},
#   {'Text': 'here so input tokens output', 'TimeStamp': 3210.4},
#   {'Text': 'tokens and this one is output tokens', 'TimeStamp': 3221.64},
#   {'Text': 'right okay so we have our cost else', 'TimeStamp': 3232.28},
#   {'Text': 'uh', 'TimeStamp': 3236.96},
#   {'Text': 'print yeah so maybe we should even uh', 'TimeStamp': 3240.839},
#   {'Text': "raise an exception here or i don't know", 'TimeStamp': 3245.04},
#   {'Text': 'do something um right now i know that we', 'TimeStamp': 3246.799},
#   {'Text': 'will not use anything else apart from', 'TimeStamp': 3249.799},
#   {'Text': 'this model but of course like this we', 'TimeStamp': 3252.04},
#   {'Text': 'have to', 'TimeStamp': 3256.4},
#   {'Text': 'be we have to let the user know that', 'TimeStamp': 3257.48},
#   {'Text': 'this part of the implementation is', 'TimeStamp': 3260.92},
#   {'Text': 'missing if we want to start using', 'TimeStamp': 3263.04},
#   {'Text': 'something else', 'TimeStamp': 3264.76},
#   {'Text': 'okay so now we just need to', 'TimeStamp': 3270.16},
#   {'Text': 'add', 'TimeStamp': 3274.16},
#   {'Text': 'um where is', 'TimeStamp': 3276.4},
#   {'Text': 'it we need to add', 'TimeStamp': 3278.48},
#   {'Text': 'this open ai', 'TimeStamp': 3281.48},
#   {'Text': 'cost and actually like this model', 'TimeStamp': 3284.92},
#   {'Text': 'tokens', 'TimeStamp': 3289.64},
#   {'Text': 'model to starts', 'TimeStamp': 3292.68},
#   {'Text': 'answer or', 'TimeStamp': 3300.2},
#   {'Text': 'rock of all and total cost will', 'TimeStamp': 3302.4},
#   {'Text': 'be yeah this one so now we have the', 'TimeStamp': 3308.599},
#   {'Text': 'costs and yeah now we just need to hope', 'TimeStamp': 3314.079},
#   {'Text': 'that it still works let me format the', 'TimeStamp': 3317.48},
#   {'Text': 'file one more time', 'TimeStamp': 3319.599},
#   {'Text': 'see what we have in our', 'TimeStamp': 3326.48},
#   {'Text': 'terminal okay well atly', 'TimeStamp': 3338.24},
#   {'Text': 'started now let', 'TimeStamp': 3342.24},
#   {'Text': 'me run the', 'TimeStamp': 3344.52},
#   {'Text': 'test okay something is', 'TimeStamp': 3350.079},
#   {'Text': 'wrong iation prom template format', 'TimeStamp': 3353.2},
#   {'Text': 'yeah here we need to', 'TimeStamp': 3359.24},
#   {'Text': 'use just', 'TimeStamp': 3361.799},
#   {'Text': 'answer', 'TimeStamp': 3364.28},
#   {'Text': 'yeah okay so now we saved everything to', 'TimeStamp': 3377.4},
#   {'Text': 'the', 'TimeStamp': 3380.4},
#   {'Text': 'database', 'TimeStamp': 3381.16},
#   {'Text': "and yeah i don't know if i should show", 'TimeStamp': 3383.359},
#   {'Text': 'now how to set up grafana should be', 'TimeStamp': 3386.4},
#   {'Text': 'relatively straightforward so you go to', 'TimeStamp': 3389.799},
#   {'Text': 'local', 'TimeStamp': 3391.599},
#   {'Text': "host and then what's", 'TimeStamp': 3392.48},
#   {'Text': 'the where is our doer compos for grafana', 'TimeStamp': 3398.24},
#   {'Text': '3,000 and what we can do is we can just', 'TimeStamp': 3405.319},
#   {'Text': 'take is it admin admin', 'TimeStamp': 3408.64},
#   {'Text': 'wait yeah', 'TimeStamp': 3420.68},
#   {'Text': 'whatever and uh yeah so we just need to', 'TimeStamp': 3429.44},
#   {'Text': 'do the same thing we did', 'TimeStamp': 3432.64},
#   {'Text': 'previously we also have in', 'TimeStamp': 3434.88},
#   {'Text': 'our course i think we', 'TimeStamp': 3439.2},
#   {'Text': 'saved the dashboard right so now i can', 'TimeStamp': 3443.44},
#   {'Text': 'just download', 'TimeStamp': 3447.119},
#   {'Text': 'it think i will also need to update the', 'TimeStamp': 3451.72},
#   {'Text': 'data source', 'TimeStamp': 3454.44},
#   {'Text': 'right in multiple times but now you know', 'TimeStamp': 3457.64},
#   {'Text': 'what to do right so you just add the', 'TimeStamp': 3460.4},
#   {'Text': 'data source to grafana in this one uh', 'TimeStamp': 3462.16},
#   {'Text': 'this is something i will add to the', 'TimeStamp': 3465.24},
#   {'Text': 'instructions so i will add this', 'TimeStamp': 3466.799},
#   {'Text': 'dashboard i will add to the instructions', 'TimeStamp': 3468.799},
#   {'Text': 'how exactly to set up', 'TimeStamp': 3470.799},
#   {'Text': "grafana i just don't want to spend time", 'TimeStamp': 3472.48},
#   {'Text': 'now and take to 20 minutes uh of your', 'TimeStamp': 3474.839},
#   {'Text': 'time again um because this is relatively', 'TimeStamp': 3477.96},
#   {'Text': 'straightforward now so so what i want to', 'TimeStamp': 3480.76},
#   {'Text': 'do is add the instructions on how to do', 'TimeStamp': 3483.44},
#   {'Text': "that i'll actually do this first but", 'TimeStamp': 3487.48},
#   {'Text': "then add the instructions so it's", 'TimeStamp': 3489.839},
#   {'Text': 'totally reproducible and then add a', 'TimeStamp': 3491.319},
#   {'Text': 'screenshot of that and probably in the', 'TimeStamp': 3493.72},
#   {'Text': "next video i'll just show you the", 'TimeStamp': 3496.76},
#   {'Text': "results okay that's all for now we have", 'TimeStamp': 3497.96},
#   {'Text': 'done a lot of work so', 'TimeStamp': 3500.88},
#   {'Text': 'we uh added', 'TimeStamp': 3503.559},
#   {'Text': 'let me actually see what we', 'TimeStamp': 3506.68},
#   {'Text': 'did so we added conization we added and', 'TimeStamp': 3510.039},
#   {'Text': 'we added', 'TimeStamp': 3514.24},
#   {'Text': 'monitoring', 'TimeStamp': 3515.68},
#   {'Text': 'right okay so we just have uh one last', 'TimeStamp': 3518.119},
#   {'Text': "video about best practices i don't know", 'TimeStamp': 3522.4},
#   {'Text': 'if i want to record this or not maybe', 'TimeStamp': 3524.16},
#   {'Text': "i'll just like i i think you get the", 'TimeStamp': 3527.359},
#   {'Text': 'idea you just follow what we did in the', 'TimeStamp': 3530.839},
#   {'Text': 'videos um in the course videos you copy', 'TimeStamp': 3533.0},
#   {'Text': 'the code from there you tweak it to your', 'TimeStamp': 3535.76},
#   {'Text': 'use case and then you show right so um', 'TimeStamp': 3538.319},
#   {'Text': "yeah maybe i'll show it i don't know but", 'TimeStamp': 3542.799},
#   {'Text': "for now i'm kind of tired of recording i", 'TimeStamp': 3544.88},
#   {'Text': 'just want to um record one more video', 'TimeStamp': 3546.88},
#   {'Text': 'kind of summary and then later maybe', 'TimeStamp': 3550.68},
#   {'Text': "i'll record more but this project will", 'TimeStamp': 3553.96},
#   {'Text': 'definitely pass because we would get two', 'TimeStamp': 3557.839},
#   {'Text': 'points according to criteria for this', 'TimeStamp': 3560.319},
#   {'Text': 'for this for this for', 'TimeStamp': 3564.92},
#   {'Text': 'this for this for this for', 'TimeStamp': 3568.68},
#   {'Text': 'this for this and hopefully for this', 'TimeStamp': 3573.88},
#   {'Text': 'when i finish uh the read me when i add', 'TimeStamp': 3576.92},
#   {'Text': 'all the instructions for grafana uh', 'TimeStamp': 3580.039},
#   {'Text': 'right now we will not add any points for', 'TimeStamp': 3582.52},
#   {'Text': 'this and for this but this is just one', 'TimeStamp': 3584.68},
#   {'Text': 'two three five points so with this', 'TimeStamp': 3586.96},
#   {'Text': 'project you would definitely pass okay', 'TimeStamp': 3590.48},
#   {'Text': 'that has been fun a bit long but fun so', 'TimeStamp': 3594.119},
#   {'Text': 'see you in next video in the summary', 'TimeStamp': 3597.92},
#   {'Text': "video right now i'll work on the readme", 'TimeStamp': 3599.52},
#   {'Text': 'file and i want to show you the final', 'TimeStamp': 3601.92},
#   {'Text': 'results and then share some closing', 'TimeStamp': 3603.4},
#   {'Text': 'notes so see you soon', 'TimeStamp': 3605.319}]}

# %%
# Out:
#   File "/tmp/ipykernel_2556450/1837333116.py", line 1
#     Can you write code that would create three elasticsearch indexes transcripts, timestamps and links for the following data?
#         ^
# SyntaxError: invalid syntax
